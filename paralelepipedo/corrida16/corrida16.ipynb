# %% [markdown]
# # Definiciones

# %%
import openmc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob


def run_simulation(
    fuente: list,
    geometria: list,
    z0: float,
    z_track: float,
    N_particles: int,
    ww: bool,
    batches: int = 1000,
    statepoint_file: str = None,
) -> None:
    """
    Ejecuta una simulación en OpenMC con la configuración especificada.

    Parámetros:
        fuente (list):
            - Si tiene 1 elemento: se asume que es la ruta a un archivo de fuente.
            - Si tiene 2 elementos: se asume que es [fuente_energia, fuente_direccion] para fuente independiente.
                - fuente_energia puede ser:
                    - "monoenergetica": Fuente con energía fija.
                    - "espectro_fision": Fuente con espectro de fisión.
                    - "espectro_termico": Fuente con espectro térmico.
                - fuente_direccion puede ser:
                    - "colimada": Fuente con dirección fija.
                    - "isotropica": Fuente con distribución isotrópica.

        geometria (list): Parámetros geométricos:
            - geometria[0] (bool): Flag para indicar si existe región de vacío.
            - geometria[1] (float): L_x, ancho del paralelepípedo.
            - geometria[2] (float): L_y, ancho del paralelepípedo.
            - geometria[3] (float): L_z, altura del paralelepípedo.
            - Si geometria[0] es True, se esperan además:
                - geometria[4] (float): L_x_vacio.
                - geometria[5] (float): L_y_vacio.

        z0 (float): Posición en z donde empieza la simulación.
        z_track (float): Posición en z para la superficie de track.
        N_particles (int): Número de partículas a simular en total.
        outfile_name (str): Nombre del archivo de salida. Si es None, se usa el nombre por defecto.
        WW (bool): Si se activa, se generan weight windows.
    """
    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Configuración de secciones eficaces
    # ---------------------------------------------------------------------------------------------------------------------------------------
    openmc.config["cross_sections"] = (
        "/home/lucas/Documents/Proyecto_Integrador/endfb-viii.0-hdf5/cross_sections.xml"
    )

    # ----------------------------------------------------------------------------------------------------------------------------------------
    # Procesamiento de la fuente
    # ----------------------------------------------------------------------------------------------------------------------------------------
    # Si la longitud de la fuente es 1, se asume que es un archivo de fuente.
    # Si la longitud de la fuente es 2, se asume que es una fuente independiente.
    if len(fuente) == 1:
        # Procesar fuente cuando viene de archivo
        ruta_fuente = fuente[0]
        if ruta_fuente.lower().endswith(".xml"):
            # Si es un XML de OpenMC, leerlo con el parser de fuentes
            source = openmc.HistogramSource(
                path=ruta_fuente,
            )
        else:
            # Si no es XML, asumimos formato binario o HDF5 compatible con FileSource
            source = openmc.FileSource(ruta_fuente)
    elif len(fuente) == 2:
        fuente_energia, fuente_direccion = fuente
        source = openmc.IndependentSource()
        source.particle = "neutron"

        # Distribución espacial: se coloca en la región central de la geometría
        L_x, L_y = geometria[1], geometria[2]
        x_dist = openmc.stats.Uniform(-L_x / 2, L_x / 2)
        y_dist = openmc.stats.Uniform(-L_y / 2, L_y / 2)
        z_dist = openmc.stats.Discrete(z0 + 1e-6, 1)  # Se fija z muy cerca de z=0
        source.space = openmc.stats.CartesianIndependent(x_dist, y_dist, z_dist)

        # Distribución de energía
        if fuente_energia == "monoenergetica":
            source.energy = openmc.stats.Discrete([1e6], [1])

        # Distribución angular
        if fuente_direccion == "colimada":
            mu = openmc.stats.Discrete([1], [1])
            phi = openmc.stats.Uniform(0.0, 2 * np.pi)
            source.angle = openmc.stats.PolarAzimuthal(mu, phi)
    else:
        raise ValueError("El parámetro 'fuente' debe contener 1 o 2 elementos.")

    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Procesamiento de la geometría
    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Extraer parámetros geométricos
    vacio = geometria[0]
    L_x, L_y, L_z = geometria[1:4]
    if vacio:
        L_x_vacio, L_y_vacio = geometria[4:6]

    # Definir material: agua
    mat_agua = openmc.Material(name="agua")
    mat_agua.add_nuclide("H1", 2.0, "ao")
    mat_agua.add_nuclide("O16", 1.0, "ao")
    mat_agua.add_s_alpha_beta("c_H_in_H2O")
    mat_agua.set_density("g/cm3", 1.0)
    mats = openmc.Materials([mat_agua])
    mats.export_to_xml()

    # Definir superficies externas
    surfaces = {
        "x_min": openmc.XPlane(x0=-L_x / 2, boundary_type="vacuum"),
        "x_max": openmc.XPlane(x0=L_x / 2, boundary_type="vacuum"),
        "y_min": openmc.YPlane(y0=-L_y / 2, boundary_type="vacuum"),
        "y_max": openmc.YPlane(y0=L_y / 2, boundary_type="vacuum"),
        "z_min": openmc.ZPlane(z0=z0, boundary_type="vacuum"),
        "z_max": openmc.ZPlane(z0=L_z, boundary_type="vacuum"),
    }

    # Se agrega la superficie de registro para generar el track file
    if z_track is not None:
        surfaces.update(
            {
                "z_track": openmc.ZPlane(
                    z0=z_track, boundary_type="transmission", surface_id=70
                )
            }
        )

    # Si hay vacío, definir superficies internas
    if vacio:
        surfaces.update(
            {
                "x_min_vacio": openmc.XPlane(
                    x0=-L_x_vacio / 2, boundary_type="transmission"
                ),
                "x_max_vacio": openmc.XPlane(
                    x0=L_x_vacio / 2, boundary_type="transmission"
                ),
                "y_min_vacio": openmc.YPlane(
                    y0=-L_y_vacio / 2, boundary_type="transmission"
                ),
                "y_max_vacio": openmc.YPlane(
                    y0=L_y_vacio / 2, boundary_type="transmission"
                ),
            }
        )

    # Para fuente tipo FileSource se traduce la superficie inferior para posicionar z0.
    # Sino se hace entonces las particulas aparecer fuera de la geometria.
    if len(fuente) == 1:
        surfaces["z_min"].translate(vector=(0, 0, -1e-6), inplace=True)

    # Definir regiones
    region_externa = (
        +surfaces["x_min"]
        & -surfaces["x_max"]
        & +surfaces["y_min"]
        & -surfaces["y_max"]
        & +surfaces["z_min"]
        & -surfaces["z_max"]
    )

    if vacio:
        region_vacio = (
            +surfaces["x_min_vacio"]
            & -surfaces["x_max_vacio"]
            & +surfaces["y_min_vacio"]
            & -surfaces["y_max_vacio"]
            & +surfaces["z_min"]
            & -surfaces["z_max"]
        )

    # Crear universo y definir celdas según configuración de fuente y vacío
    universe = openmc.Universe()

    if vacio:
        if z_track is not None:
            universe.add_cell(
                openmc.Cell(
                    region=region_externa & ~region_vacio & -surfaces["z_track"],
                    fill=mat_agua,
                    name="agua1",
                )
            )
            universe.add_cell(
                openmc.Cell(
                    region=region_externa & ~region_vacio & +surfaces["z_track"],
                    fill=mat_agua,
                    name="agua2",
                )
            )
            universe.add_cell(
                openmc.Cell(
                    region=region_vacio & -surfaces["z_track"],
                    fill=None,
                    name="vacio1",
                )
            )
            universe.add_cell(
                openmc.Cell(
                    region=region_vacio & +surfaces["z_track"],
                    fill=None,
                    name="vacio2",
                )
            )
        else:
            universe.add_cell(
                openmc.Cell(
                    region=region_externa & ~region_vacio,
                    fill=mat_agua,
                    name="agua",
                )
            )
            universe.add_cell(openmc.Cell(region=region_vacio, fill=None, name="vacio"))
    else:
        if z_track is not None:
            universe.add_cell(
                openmc.Cell(
                    region=region_externa & -surfaces["z_track"],
                    fill=mat_agua,
                    name="agua1",
                )
            )
            universe.add_cell(
                openmc.Cell(
                    region=region_externa & +surfaces["z_track"],
                    fill=mat_agua,
                    name="agua2",
                )
            )
        else:
            universe.add_cell(
                openmc.Cell(region=region_externa, fill=mat_agua, name="agua")
            )

    geom = openmc.Geometry(universe)
    geom.export_to_xml()

    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Configuración de settings
    # ---------------------------------------------------------------------------------------------------------------------------------------
    settings = openmc.Settings()
    settings.surf_source_write = {"surface_ids": [70], "max_particles": 20000000}
    settings.run_mode = "fixed source"
    settings.batches = batches
    settings.particles = int(N_particles)
    settings.source = source

    # Se definen las ventanas de peso
    if ww:
        # Define weight window spatial mesh
        ww_mesh = openmc.RegularMesh()
        ww_mesh.dimension = (10, 10, 100)
        ww_mesh.lower_left = (-L_x / 2, -L_y / 2, z0)
        ww_mesh.upper_right = (L_x / 2, L_y / 2, L_z)

        # Create weight window object and adjust parameters
        wwg = openmc.WeightWindowGenerator(
            method="magic",
            mesh=ww_mesh,
            max_realizations=settings.batches,
            energy_bounds=[0, 1, 1e3, 1e7],
            update_interval=50,
        )

        # Add generator to Settings instance
        settings.weight_window_generators = wwg
    settings.export_to_xml()

    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Configuración de tallies
    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Tally: malla para flujo total
    mesh = openmc.RectilinearMesh()
    mesh.x_grid = np.linspace(-L_x / 2, L_x / 2, 2)
    mesh.y_grid = np.linspace(-L_y / 2, L_y / 2, 2)
    mesh.z_grid = np.linspace(z0, L_z, 51)
    mesh_filter = openmc.MeshFilter(mesh)
    tally_flux_total = openmc.Tally(name="flux_total")
    tally_flux_total.filters = [mesh_filter]
    tally_flux_total.scores = ["flux"]

    # Tally: malla para flujo en vacio
    if vacio:
        mesh_vacio = openmc.RectilinearMesh()
        mesh_vacio.x_grid = np.linspace(-L_x_vacio / 2, L_x_vacio / 2, 2)
        mesh_vacio.y_grid = np.linspace(-L_y_vacio / 2, L_y_vacio / 2, 2)
        mesh_vacio.z_grid = np.linspace(z0, L_z, 51)
        mesh_filter_vacio = openmc.MeshFilter(mesh_vacio)
        tally_flux_vacio = openmc.Tally(name="flux_vacio")
        tally_flux_vacio.filters = [mesh_filter_vacio]
        tally_flux_vacio.scores = ["flux"]

    tallies = openmc.Tallies(
        [tally_flux_total, tally_flux_vacio] if vacio else [tally_flux_total]
    )

    tallies.export_to_xml()

    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Limpieza de archivos previos y ejecución de la simulación
    # ---------------------------------------------------------------------------------------------------------------------------------------
    if statepoint_file is None:
        for file in glob.glob("statepoint.*.h5"):
            os.remove(file)
        if os.path.exists("summary.h5"):
            os.remove("summary.h5")

        openmc.run()
    else:
        openmc.run(restart_file=statepoint_file)

# %% [markdown]
# # Configuracion

# %%
geometria = [True, 15, 15, 100, 3, 3]
z0 = 0
fuente = ["monoenergetica", "colimada"]
z_track = 80
num_particles = int(5e3)
batches = 14000
WW = True
simulaciones_hechas = 15
simulaciones_por_hacer = 3

# for i in range(simulaciones_por_hacer):
#     sim_dir = f"sim{i+1+simulaciones_hechas}"
#     os.makedirs(sim_dir, exist_ok=True)
#     os.chdir(sim_dir)
#     print(f"Ejecutando simulación {i+1}")
#     run_simulation(
#         fuente=fuente,
#         geometria=geometria,
#         z0=z0,
#         z_track=z_track,
#         N_particles=num_particles,
#         ww=WW,
#     )
#     os.chdir("..")

run_simulation(
    fuente=fuente,
    geometria=geometria,
    z0=z0,
    z_track=z_track,
    N_particles=num_particles,
    batches=batches,
    ww=WW,
    statepoint_file="statepoint.11000.h5",
)

# Renombrar el archivo surface_source.h5 para incluir el número de batches
if os.path.exists('surface_source.h5'):
    os.rename('surface_source.h5', f'surface_source_{batches}.h5')
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2024 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.1-dev
#        Date/Time | 2025-05-19 20:06:24
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H1 from
#  /home/lucas/Documents/Proyecto_Integrador/endfb-viii.0-hdf5/neutron/H1.h5
#  Reading O16 from
#  /home/lucas/Documents/Proyecto_Integrador/endfb-viii.0-hdf5/neutron/O16.h5
#  Reading c_H_in_H2O from
#  /home/lucas/Documents/Proyecto_Integrador/endfb-viii.0-hdf5/neutron/c_H_in_H2O.h
#  5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Loading state point statepoint.11000.h5...
#  Resuming simulation...
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 11001
#  Simulating batch 11002
#  Simulating batch 11003
#  Simulating batch 11004
#  Simulating batch 11005
#  Simulating batch 11006
#  Simulating batch 11007
#  Simulating batch 11008
#  Simulating batch 11009
#  Simulating batch 11010
#  Simulating batch 11011
#  Simulating batch 11012
#  Simulating batch 11013
#  Simulating batch 11014
#  Simulating batch 11015
#  Simulating batch 11016
#  Simulating batch 11017
#  Simulating batch 11018
#  Simulating batch 11019
#  Simulating batch 11020
#  Simulating batch 11021
#  Simulating batch 11022
#  Simulating batch 11023
#  Simulating batch 11024
#  Simulating batch 11025
#  Simulating batch 11026
#  Simulating batch 11027
#  Simulating batch 11028
#  Simulating batch 11029
#  Simulating batch 11030
#  Simulating batch 11031
#  Simulating batch 11032
#  Simulating batch 11033
#  Simulating batch 11034
#  Simulating batch 11035
#  Simulating batch 11036
#  Simulating batch 11037
#  Simulating batch 11038
#  Simulating batch 11039
#  Simulating batch 11040
#  Simulating batch 11041
#  Simulating batch 11042
#  Simulating batch 11043
#  Simulating batch 11044
#  Simulating batch 11045
#  Simulating batch 11046
#  Simulating batch 11047
#  Simulating batch 11048
#  Simulating batch 11049
#  Simulating batch 11050
#  Simulating batch 11051
#  Simulating batch 11052
#  Simulating batch 11053
#  Simulating batch 11054
#  Simulating batch 11055
#  Simulating batch 11056
#  Simulating batch 11057
#  Simulating batch 11058
#  Simulating batch 11059
#  Simulating batch 11060
#  Simulating batch 11061
#  Simulating batch 11062
#  Simulating batch 11063
#  Simulating batch 11064
#  Simulating batch 11065
#  Simulating batch 11066
#  Simulating batch 11067
#  Simulating batch 11068
#  Simulating batch 11069
#  Simulating batch 11070
#  Simulating batch 11071
#  Simulating batch 11072
#  Simulating batch 11073
#  Simulating batch 11074
#  Simulating batch 11075
#  Simulating batch 11076
#  Simulating batch 11077
#  Simulating batch 11078
#  Simulating batch 11079
#  Simulating batch 11080
#  Simulating batch 11081
#  Simulating batch 11082
#  Simulating batch 11083
#  Simulating batch 11084
#  Simulating batch 11085
#  Simulating batch 11086
#  Simulating batch 11087
#  Simulating batch 11088
#  Simulating batch 11089
#  Simulating batch 11090
#  Simulating batch 11091
#  Simulating batch 11092
#  Simulating batch 11093
#  Simulating batch 11094
#  Simulating batch 11095
#  Simulating batch 11096
#  Simulating batch 11097
#  Simulating batch 11098
#  Simulating batch 11099
#  Simulating batch 11100
#  Simulating batch 11101
#  Simulating batch 11102
#  Simulating batch 11103
#  Simulating batch 11104
#  Simulating batch 11105
#  Simulating batch 11106
#  Simulating batch 11107
#  Simulating batch 11108
#  Simulating batch 11109
#  Simulating batch 11110
#  Simulating batch 11111
#  Simulating batch 11112
#  Simulating batch 11113
#  Simulating batch 11114
#  Simulating batch 11115
#  Simulating batch 11116
#  Simulating batch 11117
#  Simulating batch 11118
#  Simulating batch 11119
#  Simulating batch 11120
#  Simulating batch 11121
#  Simulating batch 11122
#  Simulating batch 11123
#  Simulating batch 11124
#  Simulating batch 11125
#  Simulating batch 11126
#  Simulating batch 11127
#  Simulating batch 11128
#  Simulating batch 11129
#  Simulating batch 11130
#  Simulating batch 11131
#  Simulating batch 11132
#  Simulating batch 11133
#  Simulating batch 11134
#  Simulating batch 11135
#  Simulating batch 11136
#  Simulating batch 11137
#  Simulating batch 11138
#  Simulating batch 11139
#  Simulating batch 11140
#  Simulating batch 11141
#  Simulating batch 11142
#  Simulating batch 11143
#  Simulating batch 11144
#  Simulating batch 11145
#  Simulating batch 11146
#  Simulating batch 11147
#  Simulating batch 11148
#  Simulating batch 11149
#  Simulating batch 11150
#  Simulating batch 11151
#  Simulating batch 11152
#  Simulating batch 11153
#  Simulating batch 11154
#  Simulating batch 11155
#  Simulating batch 11156
#  Simulating batch 11157
#  Simulating batch 11158
#  Simulating batch 11159
#  Simulating batch 11160
#  Simulating batch 11161
#  Simulating batch 11162
#  Simulating batch 11163
#  Simulating batch 11164
#  Simulating batch 11165
#  Simulating batch 11166
#  Simulating batch 11167
#  Simulating batch 11168
#  Simulating batch 11169
#  Simulating batch 11170
#  Simulating batch 11171
#  Simulating batch 11172
#  Simulating batch 11173
#  Simulating batch 11174
#  Simulating batch 11175
#  Simulating batch 11176
#  Simulating batch 11177
#  Simulating batch 11178
#  Simulating batch 11179
#  Simulating batch 11180
#  Simulating batch 11181
#  Simulating batch 11182
#  Simulating batch 11183
#  Simulating batch 11184
#  Simulating batch 11185
#  Simulating batch 11186
#  Simulating batch 11187
#  Simulating batch 11188
#  Simulating batch 11189
#  Simulating batch 11190
#  Simulating batch 11191
#  Simulating batch 11192
#  Simulating batch 11193
#  Simulating batch 11194
#  Simulating batch 11195
#  Simulating batch 11196
#  Simulating batch 11197
#  Simulating batch 11198
#  Simulating batch 11199
#  Simulating batch 11200
#  Simulating batch 11201
#  Simulating batch 11202
#  Simulating batch 11203
#  Simulating batch 11204
#  Simulating batch 11205
#  Simulating batch 11206
#  Simulating batch 11207
#  Simulating batch 11208
#  Simulating batch 11209
#  Simulating batch 11210
#  Simulating batch 11211
#  Simulating batch 11212
#  Simulating batch 11213
#  Simulating batch 11214
#  Simulating batch 11215
#  Simulating batch 11216
#  Simulating batch 11217
#  Simulating batch 11218
#  Simulating batch 11219
#  Simulating batch 11220
#  Simulating batch 11221
#  Simulating batch 11222
#  Simulating batch 11223
#  Simulating batch 11224
#  Simulating batch 11225
#  Simulating batch 11226
#  Simulating batch 11227
#  Simulating batch 11228
#  Simulating batch 11229
#  Simulating batch 11230
#  Simulating batch 11231
#  Simulating batch 11232
#  Simulating batch 11233
#  Simulating batch 11234
#  Simulating batch 11235
#  Simulating batch 11236
#  Simulating batch 11237
#  Simulating batch 11238
#  Simulating batch 11239
#  Simulating batch 11240
#  Simulating batch 11241
#  Simulating batch 11242
#  Simulating batch 11243
#  Simulating batch 11244
#  Simulating batch 11245
#  Simulating batch 11246
#  Simulating batch 11247
#  Simulating batch 11248
#  Simulating batch 11249
#  Simulating batch 11250
#  Simulating batch 11251
#  Simulating batch 11252
#  Simulating batch 11253
#  Simulating batch 11254
#  Simulating batch 11255
#  Simulating batch 11256
#  Simulating batch 11257
#  Simulating batch 11258
#  Simulating batch 11259
#  Simulating batch 11260
#  Simulating batch 11261
#  Simulating batch 11262
#  Simulating batch 11263
#  Simulating batch 11264
#  Simulating batch 11265
#  Simulating batch 11266
#  Simulating batch 11267
#  Simulating batch 11268
#  Simulating batch 11269
#  Simulating batch 11270
#  Simulating batch 11271
#  Simulating batch 11272
#  Simulating batch 11273
#  Simulating batch 11274
#  Simulating batch 11275
#  Simulating batch 11276
#  Simulating batch 11277
#  Simulating batch 11278
#  Simulating batch 11279
#  Simulating batch 11280
#  Simulating batch 11281
#  Simulating batch 11282
#  Simulating batch 11283
#  Simulating batch 11284
#  Simulating batch 11285
#  Simulating batch 11286
#  Simulating batch 11287
#  Simulating batch 11288
#  Simulating batch 11289
#  Simulating batch 11290
#  Simulating batch 11291
#  Simulating batch 11292
#  Simulating batch 11293
#  Simulating batch 11294
#  Simulating batch 11295
#  Simulating batch 11296
#  Simulating batch 11297
#  Simulating batch 11298
#  Simulating batch 11299
#  Simulating batch 11300
#  Simulating batch 11301
#  Simulating batch 11302
#  Simulating batch 11303
#  Simulating batch 11304
#  Simulating batch 11305
#  Simulating batch 11306
#  Simulating batch 11307
#  Simulating batch 11308
#  Simulating batch 11309
#  Simulating batch 11310
#  Simulating batch 11311
#  Simulating batch 11312
#  Simulating batch 11313
#  Simulating batch 11314
#  Simulating batch 11315
#  Simulating batch 11316
#  Simulating batch 11317
#  Simulating batch 11318
#  Simulating batch 11319
#  Simulating batch 11320
#  Simulating batch 11321
#  Simulating batch 11322
#  Simulating batch 11323
#  Simulating batch 11324
#  Simulating batch 11325
#  Simulating batch 11326
#  Simulating batch 11327
#  Simulating batch 11328
#  Simulating batch 11329
#  Simulating batch 11330
#  Simulating batch 11331
#  Simulating batch 11332
#  Simulating batch 11333
#  Simulating batch 11334
#  Simulating batch 11335
#  Simulating batch 11336
#  Simulating batch 11337
#  Simulating batch 11338
#  Simulating batch 11339
#  Simulating batch 11340
#  Simulating batch 11341
#  Simulating batch 11342
#  Simulating batch 11343
#  Simulating batch 11344
#  Simulating batch 11345
#  Simulating batch 11346
#  Simulating batch 11347
#  Simulating batch 11348
#  Simulating batch 11349
#  Simulating batch 11350
#  Simulating batch 11351
#  Simulating batch 11352
#  Simulating batch 11353
#  Simulating batch 11354
#  Simulating batch 11355
#  Simulating batch 11356
#  Simulating batch 11357
#  Simulating batch 11358
#  Simulating batch 11359
#  Simulating batch 11360
#  Simulating batch 11361
#  Simulating batch 11362
#  Simulating batch 11363
#  Simulating batch 11364
#  Simulating batch 11365
#  Simulating batch 11366
#  Simulating batch 11367
#  Simulating batch 11368
#  Simulating batch 11369
#  Simulating batch 11370
#  Simulating batch 11371
#  Simulating batch 11372
#  Simulating batch 11373
#  Simulating batch 11374
#  Simulating batch 11375
#  Simulating batch 11376
#  Simulating batch 11377
#  Simulating batch 11378
#  Simulating batch 11379
#  Simulating batch 11380
#  Simulating batch 11381
#  Simulating batch 11382
#  Simulating batch 11383
#  Simulating batch 11384
#  Simulating batch 11385
#  Simulating batch 11386
#  Simulating batch 11387
#  Simulating batch 11388
#  Simulating batch 11389
#  Simulating batch 11390
#  Simulating batch 11391
#  Simulating batch 11392
#  Simulating batch 11393
#  Simulating batch 11394
#  Simulating batch 11395
#  Simulating batch 11396
#  Simulating batch 11397
#  Simulating batch 11398
#  Simulating batch 11399
#  Simulating batch 11400
#  Simulating batch 11401
#  Simulating batch 11402
#  Simulating batch 11403
#  Simulating batch 11404
#  Simulating batch 11405
#  Simulating batch 11406
#  Simulating batch 11407
#  Simulating batch 11408
#  Simulating batch 11409
#  Simulating batch 11410
#  Simulating batch 11411
#  Simulating batch 11412
#  Simulating batch 11413
#  Simulating batch 11414
#  Simulating batch 11415
#  Simulating batch 11416
#  Simulating batch 11417
#  Simulating batch 11418
#  Simulating batch 11419
#  Simulating batch 11420
#  Simulating batch 11421
#  Simulating batch 11422
#  Simulating batch 11423
#  Simulating batch 11424
#  Simulating batch 11425
#  Simulating batch 11426
#  Simulating batch 11427
#  Simulating batch 11428
#  Simulating batch 11429
#  Simulating batch 11430
#  Simulating batch 11431
#  Simulating batch 11432
#  Simulating batch 11433
#  Simulating batch 11434
#  Simulating batch 11435
#  Simulating batch 11436
#  Simulating batch 11437
#  Simulating batch 11438
#  Simulating batch 11439
#  Simulating batch 11440
#  Simulating batch 11441
#  Simulating batch 11442
#  Simulating batch 11443
#  Simulating batch 11444
#  Simulating batch 11445
#  Simulating batch 11446
#  Simulating batch 11447
#  Simulating batch 11448
#  Simulating batch 11449
#  Simulating batch 11450
#  Simulating batch 11451
#  Simulating batch 11452
#  Simulating batch 11453
#  Simulating batch 11454
#  Simulating batch 11455
#  Simulating batch 11456
#  Simulating batch 11457
#  Simulating batch 11458
#  Simulating batch 11459
#  Simulating batch 11460
#  Simulating batch 11461
#  Simulating batch 11462
#  Simulating batch 11463
#  Simulating batch 11464
#  Simulating batch 11465
#  Simulating batch 11466
#  Simulating batch 11467
#  Simulating batch 11468
#  Simulating batch 11469
#  Simulating batch 11470
#  Simulating batch 11471
#  Simulating batch 11472
#  Simulating batch 11473
#  Simulating batch 11474
#  Simulating batch 11475
#  Simulating batch 11476
#  Simulating batch 11477
#  Simulating batch 11478
#  Simulating batch 11479
#  Simulating batch 11480
#  Simulating batch 11481
#  Simulating batch 11482
#  Simulating batch 11483
#  Simulating batch 11484
#  Simulating batch 11485
#  Simulating batch 11486
#  Simulating batch 11487
#  Simulating batch 11488
#  Simulating batch 11489
#  Simulating batch 11490
#  Simulating batch 11491
#  Simulating batch 11492
#  Simulating batch 11493
#  Simulating batch 11494
#  Simulating batch 11495
#  Simulating batch 11496
#  Simulating batch 11497
#  Simulating batch 11498
#  Simulating batch 11499
#  Simulating batch 11500
#  Simulating batch 11501
#  Simulating batch 11502
#  Simulating batch 11503
#  Simulating batch 11504
#  Simulating batch 11505
#  Simulating batch 11506
#  Simulating batch 11507
#  Simulating batch 11508
#  Simulating batch 11509
#  Simulating batch 11510
#  Simulating batch 11511
#  Simulating batch 11512
#  Simulating batch 11513
#  Simulating batch 11514
#  Simulating batch 11515
#  Simulating batch 11516
#  Simulating batch 11517
#  Simulating batch 11518
#  Simulating batch 11519
#  Simulating batch 11520
#  Simulating batch 11521
#  Simulating batch 11522
#  Simulating batch 11523
#  Simulating batch 11524
#  Simulating batch 11525
#  Simulating batch 11526
#  Simulating batch 11527
#  Simulating batch 11528
#  Simulating batch 11529
#  Simulating batch 11530
#  Simulating batch 11531
#  Simulating batch 11532
#  Simulating batch 11533
#  Simulating batch 11534
#  Simulating batch 11535
#  Simulating batch 11536
#  Simulating batch 11537
#  Simulating batch 11538
#  Simulating batch 11539
#  Simulating batch 11540
#  Simulating batch 11541
#  Simulating batch 11542
#  Simulating batch 11543
#  Simulating batch 11544
#  Simulating batch 11545
#  Simulating batch 11546
#  Simulating batch 11547
#  Simulating batch 11548
#  Simulating batch 11549
#  Simulating batch 11550
#  Simulating batch 11551
#  Simulating batch 11552
#  Simulating batch 11553
#  Simulating batch 11554
#  Simulating batch 11555
#  Simulating batch 11556
#  Simulating batch 11557
#  Simulating batch 11558
#  Simulating batch 11559
#  Simulating batch 11560
#  Simulating batch 11561
#  Simulating batch 11562
#  Simulating batch 11563
#  Simulating batch 11564
#  Simulating batch 11565
#  Simulating batch 11566
#  Simulating batch 11567
#  Simulating batch 11568
#  Simulating batch 11569
#  Simulating batch 11570
#  Simulating batch 11571
#  Simulating batch 11572
#  Simulating batch 11573
#  Simulating batch 11574
#  Simulating batch 11575
#  Simulating batch 11576
#  Simulating batch 11577
#  Simulating batch 11578
#  Simulating batch 11579
#  Simulating batch 11580
#  Simulating batch 11581
#  Simulating batch 11582
#  Simulating batch 11583
#  Simulating batch 11584
#  Simulating batch 11585
#  Simulating batch 11586
#  Simulating batch 11587
#  Simulating batch 11588
#  Simulating batch 11589
#  Simulating batch 11590
#  Simulating batch 11591
#  Simulating batch 11592
#  Simulating batch 11593
#  Simulating batch 11594
#  Simulating batch 11595
#  Simulating batch 11596
#  Simulating batch 11597
#  Simulating batch 11598
#  Simulating batch 11599
#  Simulating batch 11600
#  Simulating batch 11601
#  Simulating batch 11602
#  Simulating batch 11603
#  Simulating batch 11604
#  Simulating batch 11605
#  Simulating batch 11606
#  Simulating batch 11607
#  Simulating batch 11608
#  Simulating batch 11609
#  Simulating batch 11610
#  Simulating batch 11611
#  Simulating batch 11612
#  Simulating batch 11613
#  Simulating batch 11614
#  Simulating batch 11615
#  Simulating batch 11616
#  Simulating batch 11617
#  Simulating batch 11618
#  Simulating batch 11619
#  Simulating batch 11620
#  Simulating batch 11621
#  Simulating batch 11622
#  Simulating batch 11623
#  Simulating batch 11624
#  Simulating batch 11625
#  Simulating batch 11626
#  Simulating batch 11627
#  Simulating batch 11628
#  Simulating batch 11629
#  Simulating batch 11630
#  Simulating batch 11631
#  Simulating batch 11632
#  Simulating batch 11633
#  Simulating batch 11634
#  Simulating batch 11635
#  Simulating batch 11636
#  Simulating batch 11637
#  Simulating batch 11638
#  Simulating batch 11639
#  Simulating batch 11640
#  Simulating batch 11641
#  Simulating batch 11642
#  Simulating batch 11643
#  Simulating batch 11644
#  Simulating batch 11645
#  Simulating batch 11646
#  Simulating batch 11647
#  Simulating batch 11648
#  Simulating batch 11649
#  Simulating batch 11650
#  Simulating batch 11651
#  Simulating batch 11652
#  Simulating batch 11653
#  Simulating batch 11654
#  Simulating batch 11655
#  Simulating batch 11656
#  Simulating batch 11657
#  Simulating batch 11658
#  Simulating batch 11659
#  Simulating batch 11660
#  Simulating batch 11661
#  Simulating batch 11662
#  Simulating batch 11663
#  Simulating batch 11664
#  Simulating batch 11665
#  Simulating batch 11666
#  Simulating batch 11667
#  Simulating batch 11668
#  Simulating batch 11669
#  Simulating batch 11670
#  Simulating batch 11671
#  Simulating batch 11672
#  Simulating batch 11673
#  Simulating batch 11674
#  Simulating batch 11675
#  Simulating batch 11676
#  Simulating batch 11677
#  Simulating batch 11678
#  Simulating batch 11679
#  Simulating batch 11680
#  Simulating batch 11681
#  Simulating batch 11682
#  Simulating batch 11683
#  Simulating batch 11684
#  Simulating batch 11685
#  Simulating batch 11686
#  Simulating batch 11687
#  Simulating batch 11688
#  Simulating batch 11689
#  Simulating batch 11690
#  Simulating batch 11691
#  Simulating batch 11692
#  Simulating batch 11693
#  Simulating batch 11694
#  Simulating batch 11695
#  Simulating batch 11696
#  Simulating batch 11697
#  Simulating batch 11698
#  Simulating batch 11699
#  Simulating batch 11700
#  Simulating batch 11701
#  Simulating batch 11702
#  Simulating batch 11703
#  Simulating batch 11704
#  Simulating batch 11705
#  Simulating batch 11706
#  Simulating batch 11707
#  Simulating batch 11708
#  Simulating batch 11709
#  Simulating batch 11710
#  Simulating batch 11711
#  Simulating batch 11712
#  Simulating batch 11713
#  Simulating batch 11714
#  Simulating batch 11715
#  Simulating batch 11716
#  Simulating batch 11717
#  Simulating batch 11718
#  Simulating batch 11719
#  Simulating batch 11720
#  Simulating batch 11721
#  Simulating batch 11722
#  Simulating batch 11723
#  Simulating batch 11724
#  Simulating batch 11725
#  Simulating batch 11726
#  Simulating batch 11727
#  Simulating batch 11728
#  Simulating batch 11729
#  Simulating batch 11730
#  Simulating batch 11731
#  Simulating batch 11732
#  Simulating batch 11733
#  Simulating batch 11734
#  Simulating batch 11735
#  Simulating batch 11736
#  Simulating batch 11737
#  Simulating batch 11738
#  Simulating batch 11739
#  Simulating batch 11740
#  Simulating batch 11741
#  Simulating batch 11742
#  Simulating batch 11743
#  Simulating batch 11744
#  Simulating batch 11745
#  Simulating batch 11746
#  Simulating batch 11747
#  Simulating batch 11748
#  Simulating batch 11749
#  Simulating batch 11750
#  Simulating batch 11751
#  Simulating batch 11752
#  Simulating batch 11753
#  Simulating batch 11754
#  Simulating batch 11755
#  Simulating batch 11756
#  Simulating batch 11757
#  Simulating batch 11758
#  Simulating batch 11759
#  Simulating batch 11760
#  Simulating batch 11761
#  Simulating batch 11762
#  Simulating batch 11763
#  Simulating batch 11764
#  Simulating batch 11765
#  Simulating batch 11766
#  Simulating batch 11767
#  Simulating batch 11768
#  Simulating batch 11769
#  Simulating batch 11770
#  Simulating batch 11771
#  Simulating batch 11772
#  Simulating batch 11773
#  Simulating batch 11774
#  Simulating batch 11775
#  Simulating batch 11776
#  Simulating batch 11777
#  Simulating batch 11778
#  Simulating batch 11779
#  Simulating batch 11780
#  Simulating batch 11781
#  Simulating batch 11782
#  Simulating batch 11783
#  Simulating batch 11784
#  Simulating batch 11785
#  Simulating batch 11786
#  Simulating batch 11787
#  Simulating batch 11788
#  Simulating batch 11789
#  Simulating batch 11790
#  Simulating batch 11791
#  Simulating batch 11792
#  Simulating batch 11793
#  Simulating batch 11794
#  Simulating batch 11795
#  Simulating batch 11796
#  Simulating batch 11797
#  Simulating batch 11798
#  Simulating batch 11799
#  Simulating batch 11800
#  Simulating batch 11801
#  Simulating batch 11802
#  Simulating batch 11803
#  Simulating batch 11804
#  Simulating batch 11805
#  Simulating batch 11806
#  Simulating batch 11807
#  Simulating batch 11808
#  Simulating batch 11809
#  Simulating batch 11810
#  Simulating batch 11811
#  Simulating batch 11812
#  Simulating batch 11813
#  Simulating batch 11814
#  Simulating batch 11815
#  Simulating batch 11816
#  Simulating batch 11817
#  Simulating batch 11818
#  Simulating batch 11819
#  Simulating batch 11820
#  Simulating batch 11821
#  Simulating batch 11822
#  Simulating batch 11823
#  Simulating batch 11824
#  Simulating batch 11825
#  Simulating batch 11826
#  Simulating batch 11827
#  Simulating batch 11828
#  Simulating batch 11829
#  Simulating batch 11830
#  Simulating batch 11831
#  Simulating batch 11832
#  Simulating batch 11833
#  Simulating batch 11834
#  Simulating batch 11835
#  Simulating batch 11836
#  Simulating batch 11837
#  Simulating batch 11838
#  Simulating batch 11839
#  Simulating batch 11840
#  Simulating batch 11841
#  Simulating batch 11842
#  Simulating batch 11843
#  Simulating batch 11844
#  Simulating batch 11845
#  Simulating batch 11846
#  Simulating batch 11847
#  Simulating batch 11848
#  Simulating batch 11849
#  Simulating batch 11850
#  Simulating batch 11851
#  Simulating batch 11852
#  Simulating batch 11853
#  Simulating batch 11854
#  Simulating batch 11855
#  Simulating batch 11856
#  Simulating batch 11857
#  Simulating batch 11858
#  Simulating batch 11859
#  Simulating batch 11860
#  Simulating batch 11861
#  Simulating batch 11862
#  Simulating batch 11863
#  Simulating batch 11864
#  Simulating batch 11865
#  Simulating batch 11866
#  Simulating batch 11867
#  Simulating batch 11868
#  Simulating batch 11869
#  Simulating batch 11870
#  Simulating batch 11871
#  Simulating batch 11872
#  Simulating batch 11873
#  Simulating batch 11874
#  Simulating batch 11875
#  Simulating batch 11876
#  Simulating batch 11877
#  Simulating batch 11878
#  Simulating batch 11879
#  Simulating batch 11880
#  Simulating batch 11881
#  Simulating batch 11882
#  Simulating batch 11883
#  Simulating batch 11884
#  Simulating batch 11885
#  Simulating batch 11886
#  Simulating batch 11887
#  Simulating batch 11888
#  Simulating batch 11889
#  Simulating batch 11890
#  Simulating batch 11891
#  Simulating batch 11892
#  Simulating batch 11893
#  Simulating batch 11894
#  Simulating batch 11895
#  Simulating batch 11896
#  Simulating batch 11897
#  Simulating batch 11898
#  Simulating batch 11899
#  Simulating batch 11900
#  Simulating batch 11901
#  Simulating batch 11902
#  Simulating batch 11903
#  Simulating batch 11904
#  Simulating batch 11905
#  Simulating batch 11906
#  Simulating batch 11907
#  Simulating batch 11908
#  Simulating batch 11909
#  Simulating batch 11910
#  Simulating batch 11911
#  Simulating batch 11912
#  Simulating batch 11913
#  Simulating batch 11914
#  Simulating batch 11915
#  Simulating batch 11916
#  Simulating batch 11917
#  Simulating batch 11918
#  Simulating batch 11919
#  Simulating batch 11920
#  Simulating batch 11921
#  Simulating batch 11922
#  Simulating batch 11923
#  Simulating batch 11924
#  Simulating batch 11925
#  Simulating batch 11926
#  Simulating batch 11927
#  Simulating batch 11928
#  Simulating batch 11929
#  Simulating batch 11930
#  Simulating batch 11931
#  Simulating batch 11932
#  Simulating batch 11933
#  Simulating batch 11934
#  Simulating batch 11935
#  Simulating batch 11936
#  Simulating batch 11937
#  Simulating batch 11938
#  Simulating batch 11939
#  Simulating batch 11940
#  Simulating batch 11941
#  Simulating batch 11942
#  Simulating batch 11943
#  Simulating batch 11944
#  Simulating batch 11945
#  Simulating batch 11946
#  Simulating batch 11947
#  Simulating batch 11948
#  Simulating batch 11949
#  Simulating batch 11950
#  Simulating batch 11951
#  Simulating batch 11952
#  Simulating batch 11953
#  Simulating batch 11954
#  Simulating batch 11955
#  Simulating batch 11956
#  Simulating batch 11957
#  Simulating batch 11958
#  Simulating batch 11959
#  Simulating batch 11960
#  Simulating batch 11961
#  Simulating batch 11962
#  Simulating batch 11963
#  Simulating batch 11964
#  Simulating batch 11965
#  Simulating batch 11966
#  Simulating batch 11967
#  Simulating batch 11968
#  Simulating batch 11969
#  Simulating batch 11970
#  Simulating batch 11971
#  Simulating batch 11972
#  Simulating batch 11973
#  Simulating batch 11974
#  Simulating batch 11975
#  Simulating batch 11976
#  Simulating batch 11977
#  Simulating batch 11978
#  Simulating batch 11979
#  Simulating batch 11980
#  Simulating batch 11981
#  Simulating batch 11982
#  Simulating batch 11983
#  Simulating batch 11984
#  Simulating batch 11985
#  Simulating batch 11986
#  Simulating batch 11987
#  Simulating batch 11988
#  Simulating batch 11989
#  Simulating batch 11990
#  Simulating batch 11991
#  Simulating batch 11992
#  Simulating batch 11993
#  Simulating batch 11994
#  Simulating batch 11995
#  Simulating batch 11996
#  Simulating batch 11997
#  Simulating batch 11998
#  Simulating batch 11999
#  Simulating batch 12000
#  Simulating batch 12001
#  Simulating batch 12002
#  Simulating batch 12003
#  Simulating batch 12004
#  Simulating batch 12005
#  Simulating batch 12006
#  Simulating batch 12007
#  Simulating batch 12008
#  Simulating batch 12009
#  Simulating batch 12010
#  Simulating batch 12011
#  Simulating batch 12012
#  Simulating batch 12013
#  Simulating batch 12014
#  Simulating batch 12015
#  Simulating batch 12016
#  Simulating batch 12017
#  Simulating batch 12018
#  Simulating batch 12019
#  Simulating batch 12020
#  Simulating batch 12021
#  Simulating batch 12022
#  Simulating batch 12023
#  Simulating batch 12024
#  Simulating batch 12025
#  Simulating batch 12026
#  Simulating batch 12027
#  Simulating batch 12028
#  Simulating batch 12029
#  Simulating batch 12030
#  Simulating batch 12031
#  Simulating batch 12032
#  Simulating batch 12033
#  Simulating batch 12034
#  Simulating batch 12035
#  Simulating batch 12036
#  Simulating batch 12037
#  Simulating batch 12038
#  Simulating batch 12039
#  Simulating batch 12040
#  Simulating batch 12041
#  Simulating batch 12042
#  Simulating batch 12043
#  Simulating batch 12044
#  Simulating batch 12045
#  Simulating batch 12046
#  Simulating batch 12047
#  Simulating batch 12048
#  Simulating batch 12049
#  Simulating batch 12050
#  Simulating batch 12051
#  Simulating batch 12052
#  Simulating batch 12053
#  Simulating batch 12054
#  Simulating batch 12055
#  Simulating batch 12056
#  Simulating batch 12057
#  Simulating batch 12058
#  Simulating batch 12059
#  Simulating batch 12060
#  Simulating batch 12061
#  Simulating batch 12062
#  Simulating batch 12063
#  Simulating batch 12064
#  Simulating batch 12065
#  Simulating batch 12066
#  Simulating batch 12067
#  Simulating batch 12068
#  Simulating batch 12069
#  Simulating batch 12070
#  Simulating batch 12071
#  Simulating batch 12072
#  Simulating batch 12073
#  Simulating batch 12074
#  Simulating batch 12075
#  Simulating batch 12076
#  Simulating batch 12077
#  Simulating batch 12078
#  Simulating batch 12079
#  Simulating batch 12080
#  Simulating batch 12081
#  Simulating batch 12082
#  Simulating batch 12083
#  Simulating batch 12084
#  Simulating batch 12085
#  Simulating batch 12086
#  Simulating batch 12087
#  Simulating batch 12088
#  Simulating batch 12089
#  Simulating batch 12090
#  Simulating batch 12091
#  Simulating batch 12092
#  Simulating batch 12093
#  Simulating batch 12094
#  Simulating batch 12095
#  Simulating batch 12096
#  Simulating batch 12097
#  Simulating batch 12098
#  Simulating batch 12099
#  Simulating batch 12100
#  Simulating batch 12101
#  Simulating batch 12102
#  Simulating batch 12103
#  Simulating batch 12104
#  Simulating batch 12105
#  Simulating batch 12106
#  Simulating batch 12107
#  Simulating batch 12108
#  Simulating batch 12109
#  Simulating batch 12110
#  Simulating batch 12111
#  Simulating batch 12112
#  Simulating batch 12113
#  Simulating batch 12114
#  Simulating batch 12115
#  Simulating batch 12116
#  Simulating batch 12117
#  Simulating batch 12118
#  Simulating batch 12119
#  Simulating batch 12120
#  Simulating batch 12121
#  Simulating batch 12122
#  Simulating batch 12123
#  Simulating batch 12124
#  Simulating batch 12125
#  Simulating batch 12126
#  Simulating batch 12127
#  Simulating batch 12128
#  Simulating batch 12129
#  Simulating batch 12130
#  Simulating batch 12131
#  Simulating batch 12132
#  Simulating batch 12133
#  Simulating batch 12134
#  Simulating batch 12135
#  Simulating batch 12136
#  Simulating batch 12137
#  Simulating batch 12138
#  Simulating batch 12139
#  Simulating batch 12140
#  Simulating batch 12141
#  Simulating batch 12142
#  Simulating batch 12143
#  Simulating batch 12144
#  Simulating batch 12145
#  Simulating batch 12146
#  Simulating batch 12147
#  Simulating batch 12148
#  Simulating batch 12149
#  Simulating batch 12150
#  Simulating batch 12151
#  Simulating batch 12152
#  Simulating batch 12153
#  Simulating batch 12154
#  Simulating batch 12155
#  Simulating batch 12156
#  Simulating batch 12157
#  Simulating batch 12158
#  Simulating batch 12159
#  Simulating batch 12160
#  Simulating batch 12161
#  Simulating batch 12162
#  Simulating batch 12163
#  Simulating batch 12164
#  Simulating batch 12165
#  Simulating batch 12166
#  Simulating batch 12167
#  Simulating batch 12168
#  Simulating batch 12169
#  Simulating batch 12170
#  Simulating batch 12171
#  Simulating batch 12172
#  Simulating batch 12173
#  Simulating batch 12174
#  Simulating batch 12175
#  Simulating batch 12176
#  Simulating batch 12177
#  Simulating batch 12178
#  Simulating batch 12179
#  Simulating batch 12180
#  Simulating batch 12181
#  Simulating batch 12182
#  Simulating batch 12183
#  Simulating batch 12184
#  Simulating batch 12185
#  Simulating batch 12186
#  Simulating batch 12187
#  Simulating batch 12188
#  Simulating batch 12189
#  Simulating batch 12190
#  Simulating batch 12191
#  Simulating batch 12192
#  Simulating batch 12193
#  Simulating batch 12194
#  Simulating batch 12195
#  Simulating batch 12196
#  Simulating batch 12197
#  Simulating batch 12198
#  Simulating batch 12199
#  Simulating batch 12200
#  Simulating batch 12201
#  Simulating batch 12202
#  Simulating batch 12203
#  Simulating batch 12204
#  Simulating batch 12205
#  Simulating batch 12206
#  Simulating batch 12207
#  Simulating batch 12208
#  Simulating batch 12209
#  Simulating batch 12210
#  Simulating batch 12211
#  Simulating batch 12212
#  Simulating batch 12213
#  Simulating batch 12214
#  Simulating batch 12215
#  Simulating batch 12216
#  Simulating batch 12217
#  Simulating batch 12218
#  Simulating batch 12219
#  Simulating batch 12220
#  Simulating batch 12221
#  Simulating batch 12222
#  Simulating batch 12223
#  Simulating batch 12224
#  Simulating batch 12225
#  Simulating batch 12226
#  Simulating batch 12227
#  Simulating batch 12228
#  Simulating batch 12229
#  Simulating batch 12230
#  Simulating batch 12231
#  Simulating batch 12232
#  Simulating batch 12233
#  Simulating batch 12234
#  Simulating batch 12235
#  Simulating batch 12236
#  Simulating batch 12237
#  Simulating batch 12238
#  Simulating batch 12239
#  Simulating batch 12240
#  Simulating batch 12241
#  Simulating batch 12242
#  Simulating batch 12243
#  Simulating batch 12244
#  Simulating batch 12245
#  Simulating batch 12246
#  Simulating batch 12247
#  Simulating batch 12248
#  Simulating batch 12249
#  Simulating batch 12250
#  Simulating batch 12251
#  Simulating batch 12252
#  Simulating batch 12253
#  Simulating batch 12254
#  Simulating batch 12255
#  Simulating batch 12256
#  Simulating batch 12257
#  Simulating batch 12258
#  Simulating batch 12259
#  Simulating batch 12260
#  Simulating batch 12261
#  Simulating batch 12262
#  Simulating batch 12263
#  Simulating batch 12264
#  Simulating batch 12265
#  Simulating batch 12266
#  Simulating batch 12267
#  Simulating batch 12268
#  Simulating batch 12269
#  Simulating batch 12270
#  Simulating batch 12271
#  Simulating batch 12272
#  Simulating batch 12273
#  Simulating batch 12274
#  Simulating batch 12275
#  Simulating batch 12276
#  Simulating batch 12277
#  Simulating batch 12278
#  Simulating batch 12279
#  Simulating batch 12280
#  Simulating batch 12281
#  Simulating batch 12282
#  Simulating batch 12283
#  Simulating batch 12284
#  Simulating batch 12285
#  Simulating batch 12286
#  Simulating batch 12287
#  Simulating batch 12288
#  Simulating batch 12289
#  Simulating batch 12290
#  Simulating batch 12291
#  Simulating batch 12292
#  Simulating batch 12293
#  Simulating batch 12294
#  Simulating batch 12295
#  Simulating batch 12296
#  Simulating batch 12297
#  Simulating batch 12298
#  Simulating batch 12299
#  Simulating batch 12300
#  Simulating batch 12301
#  Simulating batch 12302
#  Simulating batch 12303
#  Simulating batch 12304
#  Simulating batch 12305
#  Simulating batch 12306
#  Simulating batch 12307
#  Simulating batch 12308
#  Simulating batch 12309
#  Simulating batch 12310
#  Simulating batch 12311
#  Simulating batch 12312
#  Simulating batch 12313
#  Simulating batch 12314
#  Simulating batch 12315
#  Simulating batch 12316
#  Simulating batch 12317
#  Simulating batch 12318
#  Simulating batch 12319
#  Simulating batch 12320
#  Simulating batch 12321
#  Simulating batch 12322
#  Simulating batch 12323
#  Simulating batch 12324
#  Simulating batch 12325
#  Simulating batch 12326
#  Simulating batch 12327
#  Simulating batch 12328
#  Simulating batch 12329
#  Simulating batch 12330
#  Simulating batch 12331
#  Simulating batch 12332
#  Simulating batch 12333
#  Simulating batch 12334
#  Simulating batch 12335
#  Simulating batch 12336
#  Simulating batch 12337
#  Simulating batch 12338
#  Simulating batch 12339
#  Simulating batch 12340
#  Simulating batch 12341
#  Simulating batch 12342
#  Simulating batch 12343
#  Simulating batch 12344
#  Simulating batch 12345
#  Simulating batch 12346
#  Simulating batch 12347
#  Simulating batch 12348
#  Simulating batch 12349
#  Simulating batch 12350
#  Simulating batch 12351
#  Simulating batch 12352
#  Simulating batch 12353
#  Simulating batch 12354
#  Simulating batch 12355
#  Simulating batch 12356
#  Simulating batch 12357
#  Simulating batch 12358
#  Simulating batch 12359
#  Simulating batch 12360
#  Simulating batch 12361
#  Simulating batch 12362
#  Simulating batch 12363
#  Simulating batch 12364
#  Simulating batch 12365
#  Simulating batch 12366
#  Simulating batch 12367
#  Simulating batch 12368
#  Simulating batch 12369
#  Simulating batch 12370
#  Simulating batch 12371
#  Simulating batch 12372
#  Simulating batch 12373
#  Simulating batch 12374
#  Simulating batch 12375
#  Simulating batch 12376
#  Simulating batch 12377
#  Simulating batch 12378
#  Simulating batch 12379
#  Simulating batch 12380
#  Simulating batch 12381
#  Simulating batch 12382
#  Simulating batch 12383
#  Simulating batch 12384
#  Simulating batch 12385
#  Simulating batch 12386
#  Simulating batch 12387
#  Simulating batch 12388
#  Simulating batch 12389
#  Simulating batch 12390
#  Simulating batch 12391
#  Simulating batch 12392
#  Simulating batch 12393
#  Simulating batch 12394
#  Simulating batch 12395
#  Simulating batch 12396
#  Simulating batch 12397
#  Simulating batch 12398
#  Simulating batch 12399
#  Simulating batch 12400
#  Simulating batch 12401
#  Simulating batch 12402
#  Simulating batch 12403
#  Simulating batch 12404
#  Simulating batch 12405
#  Simulating batch 12406
#  Simulating batch 12407
#  Simulating batch 12408
#  Simulating batch 12409
#  Simulating batch 12410
#  Simulating batch 12411
#  Simulating batch 12412
#  Simulating batch 12413
#  Simulating batch 12414
#  Simulating batch 12415
#  Simulating batch 12416
#  Simulating batch 12417
#  Simulating batch 12418
#  Simulating batch 12419
#  Simulating batch 12420
#  Simulating batch 12421
#  Simulating batch 12422
#  Simulating batch 12423
#  Simulating batch 12424
#  Simulating batch 12425
#  Simulating batch 12426
#  Simulating batch 12427
#  Simulating batch 12428
#  Simulating batch 12429
#  Simulating batch 12430
#  Simulating batch 12431
#  Simulating batch 12432
#  Simulating batch 12433
#  Simulating batch 12434
#  Simulating batch 12435
#  Simulating batch 12436
#  Simulating batch 12437
#  Simulating batch 12438
#  Simulating batch 12439
#  Simulating batch 12440
#  Simulating batch 12441
#  Simulating batch 12442
#  Simulating batch 12443
#  Simulating batch 12444
#  Simulating batch 12445
#  Simulating batch 12446
#  Simulating batch 12447
#  Simulating batch 12448
#  Simulating batch 12449
#  Simulating batch 12450
#  Simulating batch 12451
#  Simulating batch 12452
#  Simulating batch 12453
#  Simulating batch 12454
#  Simulating batch 12455
#  Simulating batch 12456
#  Simulating batch 12457
#  Simulating batch 12458
#  Simulating batch 12459
#  Simulating batch 12460
#  Simulating batch 12461
#  Simulating batch 12462
#  Simulating batch 12463
#  Simulating batch 12464
#  Simulating batch 12465
#  Simulating batch 12466
#  Simulating batch 12467
#  Simulating batch 12468
#  Simulating batch 12469
#  Simulating batch 12470
#  Simulating batch 12471
#  Simulating batch 12472
#  Simulating batch 12473
#  Simulating batch 12474
#  Simulating batch 12475
#  Simulating batch 12476
#  Simulating batch 12477
#  Simulating batch 12478
#  Simulating batch 12479
#  Simulating batch 12480
#  Simulating batch 12481
#  Simulating batch 12482
#  Simulating batch 12483
#  Simulating batch 12484
#  Simulating batch 12485
#  Simulating batch 12486
#  Simulating batch 12487
#  Simulating batch 12488
#  Simulating batch 12489
#  Simulating batch 12490
#  Simulating batch 12491
#  Simulating batch 12492
#  Simulating batch 12493
#  Simulating batch 12494
#  Simulating batch 12495
#  Simulating batch 12496
#  Simulating batch 12497
#  Simulating batch 12498
#  Simulating batch 12499
#  Simulating batch 12500
#  Simulating batch 12501
#  Simulating batch 12502
#  Simulating batch 12503
#  Simulating batch 12504
#  Simulating batch 12505
#  Simulating batch 12506
#  Simulating batch 12507
#  Simulating batch 12508
#  Simulating batch 12509
#  Simulating batch 12510
#  Simulating batch 12511
#  Simulating batch 12512
#  Simulating batch 12513
#  Simulating batch 12514
#  Simulating batch 12515
#  Simulating batch 12516
#  Simulating batch 12517
#  Simulating batch 12518
#  Simulating batch 12519
#  Simulating batch 12520
#  Simulating batch 12521
#  Simulating batch 12522
#  Simulating batch 12523
#  Simulating batch 12524
#  Simulating batch 12525
#  Simulating batch 12526
#  Simulating batch 12527
#  Simulating batch 12528
#  Simulating batch 12529
#  Simulating batch 12530
#  Simulating batch 12531
#  Simulating batch 12532
#  Simulating batch 12533
#  Simulating batch 12534
#  Simulating batch 12535
#  Simulating batch 12536
#  Simulating batch 12537
#  Simulating batch 12538
#  Simulating batch 12539
#  Simulating batch 12540
#  Simulating batch 12541
#  Simulating batch 12542
#  Simulating batch 12543
#  Simulating batch 12544
#  Simulating batch 12545
#  Simulating batch 12546
#  Simulating batch 12547
#  Simulating batch 12548
#  Simulating batch 12549
#  Simulating batch 12550
#  Simulating batch 12551
#  Simulating batch 12552
#  Simulating batch 12553
#  Simulating batch 12554
#  Simulating batch 12555
#  Simulating batch 12556
#  Simulating batch 12557
#  Simulating batch 12558
#  Simulating batch 12559
#  Simulating batch 12560
#  Simulating batch 12561
#  Simulating batch 12562
#  Simulating batch 12563
#  Simulating batch 12564
#  Simulating batch 12565
#  Simulating batch 12566
#  Simulating batch 12567
#  Simulating batch 12568
#  Simulating batch 12569
#  Simulating batch 12570
#  Simulating batch 12571
#  Simulating batch 12572
#  Simulating batch 12573
#  Simulating batch 12574
#  Simulating batch 12575
#  Simulating batch 12576
#  Simulating batch 12577
#  Simulating batch 12578
#  Simulating batch 12579
#  Simulating batch 12580
#  Simulating batch 12581
#  Simulating batch 12582
#  Simulating batch 12583
#  Simulating batch 12584
#  Simulating batch 12585
#  Simulating batch 12586
#  Simulating batch 12587
#  Simulating batch 12588
#  Simulating batch 12589
#  Simulating batch 12590
#  Simulating batch 12591
#  Simulating batch 12592
#  Simulating batch 12593
#  Simulating batch 12594
#  Simulating batch 12595
#  Simulating batch 12596
#  Simulating batch 12597
#  Simulating batch 12598
#  Simulating batch 12599
#  Simulating batch 12600
#  Simulating batch 12601
#  Simulating batch 12602
#  Simulating batch 12603
#  Simulating batch 12604
#  Simulating batch 12605
#  Simulating batch 12606
#  Simulating batch 12607
#  Simulating batch 12608
#  Simulating batch 12609
#  Simulating batch 12610
#  Simulating batch 12611
#  Simulating batch 12612
#  Simulating batch 12613
#  Simulating batch 12614
#  Simulating batch 12615
#  Simulating batch 12616
#  Simulating batch 12617
#  Simulating batch 12618
#  Simulating batch 12619
#  Simulating batch 12620
#  Simulating batch 12621
#  Simulating batch 12622
#  Simulating batch 12623
#  Simulating batch 12624
#  Simulating batch 12625
#  Simulating batch 12626
#  Simulating batch 12627
#  Simulating batch 12628
#  Simulating batch 12629
#  Simulating batch 12630
#  Simulating batch 12631
#  Simulating batch 12632
#  Simulating batch 12633
#  Simulating batch 12634
#  Simulating batch 12635
#  Simulating batch 12636
#  Simulating batch 12637
#  Simulating batch 12638
#  Simulating batch 12639
#  Simulating batch 12640
#  Simulating batch 12641
#  Simulating batch 12642
#  Simulating batch 12643
#  Simulating batch 12644
#  Simulating batch 12645
#  Simulating batch 12646
#  Simulating batch 12647
#  Simulating batch 12648
#  Simulating batch 12649
#  Simulating batch 12650
#  Simulating batch 12651
#  Simulating batch 12652
#  Simulating batch 12653
#  Simulating batch 12654
#  Simulating batch 12655
#  Simulating batch 12656
#  Simulating batch 12657
#  Simulating batch 12658
#  Simulating batch 12659
#  Simulating batch 12660
#  Simulating batch 12661
#  Simulating batch 12662
#  Simulating batch 12663
#  Simulating batch 12664
#  Simulating batch 12665
#  Simulating batch 12666
#  Simulating batch 12667
#  Simulating batch 12668
#  Simulating batch 12669
#  Simulating batch 12670
#  Simulating batch 12671
#  Simulating batch 12672
#  Simulating batch 12673
#  Simulating batch 12674
#  Simulating batch 12675
#  Simulating batch 12676
#  Simulating batch 12677
#  Simulating batch 12678
#  Simulating batch 12679
#  Simulating batch 12680
#  Simulating batch 12681
#  Simulating batch 12682
#  Simulating batch 12683
#  Simulating batch 12684
#  Simulating batch 12685
#  Simulating batch 12686
#  Simulating batch 12687
#  Simulating batch 12688
#  Simulating batch 12689
#  Simulating batch 12690
#  Simulating batch 12691
#  Simulating batch 12692
#  Simulating batch 12693
#  Simulating batch 12694
#  Simulating batch 12695
#  Simulating batch 12696
#  Simulating batch 12697
#  Simulating batch 12698
#  Simulating batch 12699
#  Simulating batch 12700
#  Simulating batch 12701
#  Simulating batch 12702
#  Simulating batch 12703
#  Simulating batch 12704
#  Simulating batch 12705
#  Simulating batch 12706
#  Simulating batch 12707
#  Simulating batch 12708
#  Simulating batch 12709
#  Simulating batch 12710
#  Simulating batch 12711
#  Simulating batch 12712
#  Simulating batch 12713
#  Simulating batch 12714
#  Simulating batch 12715
#  Simulating batch 12716
#  Simulating batch 12717
#  Simulating batch 12718
#  Simulating batch 12719
#  Simulating batch 12720
#  Simulating batch 12721
#  Simulating batch 12722
#  Simulating batch 12723
#  Simulating batch 12724
#  Simulating batch 12725
#  Simulating batch 12726
#  Simulating batch 12727
#  Simulating batch 12728
#  Simulating batch 12729
#  Simulating batch 12730
#  Simulating batch 12731
#  Simulating batch 12732
#  Simulating batch 12733
#  Simulating batch 12734
#  Simulating batch 12735
#  Simulating batch 12736
#  Simulating batch 12737
#  Simulating batch 12738
#  Simulating batch 12739
#  Simulating batch 12740
#  Simulating batch 12741
#  Simulating batch 12742
#  Simulating batch 12743
#  Simulating batch 12744
#  Simulating batch 12745
#  Simulating batch 12746
#  Simulating batch 12747
#  Simulating batch 12748
#  Simulating batch 12749
#  Simulating batch 12750
#  Simulating batch 12751
#  Simulating batch 12752
#  Simulating batch 12753
#  Simulating batch 12754
#  Simulating batch 12755
#  Simulating batch 12756
#  Simulating batch 12757
#  Simulating batch 12758
#  Simulating batch 12759
#  Simulating batch 12760
#  Simulating batch 12761
#  Simulating batch 12762
#  Simulating batch 12763
#  Simulating batch 12764
#  Simulating batch 12765
#  Simulating batch 12766
#  Simulating batch 12767
#  Simulating batch 12768
#  Simulating batch 12769
#  Simulating batch 12770
#  Simulating batch 12771
#  Simulating batch 12772
#  Simulating batch 12773
#  Simulating batch 12774
#  Simulating batch 12775
#  Simulating batch 12776
#  Simulating batch 12777
#  Simulating batch 12778
#  Simulating batch 12779
#  Simulating batch 12780
#  Simulating batch 12781
#  Simulating batch 12782
#  Simulating batch 12783
#  Simulating batch 12784
#  Simulating batch 12785
#  Simulating batch 12786
#  Simulating batch 12787
#  Simulating batch 12788
#  Simulating batch 12789
#  Simulating batch 12790
#  Simulating batch 12791
#  Simulating batch 12792
#  Simulating batch 12793
#  Simulating batch 12794
#  Simulating batch 12795
#  Simulating batch 12796
#  Simulating batch 12797
#  Simulating batch 12798
#  Simulating batch 12799
#  Simulating batch 12800
#  Simulating batch 12801
#  Simulating batch 12802
#  Simulating batch 12803
#  Simulating batch 12804
#  Simulating batch 12805
#  Simulating batch 12806
#  Simulating batch 12807
#  Simulating batch 12808
#  Simulating batch 12809
#  Simulating batch 12810
#  Simulating batch 12811
#  Simulating batch 12812
#  Simulating batch 12813
#  Simulating batch 12814
#  Simulating batch 12815
#  Simulating batch 12816
#  Simulating batch 12817
#  Simulating batch 12818
#  Simulating batch 12819
#  Simulating batch 12820
#  Simulating batch 12821
#  Simulating batch 12822
#  Simulating batch 12823
#  Simulating batch 12824
#  Simulating batch 12825
#  Simulating batch 12826
#  Simulating batch 12827
#  Simulating batch 12828
#  Simulating batch 12829
#  Simulating batch 12830
#  Simulating batch 12831
#  Simulating batch 12832
#  Simulating batch 12833
#  Simulating batch 12834
#  Simulating batch 12835
#  Simulating batch 12836
#  Simulating batch 12837
#  Simulating batch 12838
#  Simulating batch 12839
#  Simulating batch 12840
#  Simulating batch 12841
#  Simulating batch 12842
#  Simulating batch 12843
#  Simulating batch 12844
#  Simulating batch 12845
#  Simulating batch 12846
#  Simulating batch 12847
#  Simulating batch 12848
#  Simulating batch 12849
#  Simulating batch 12850
#  Simulating batch 12851
#  Simulating batch 12852
#  Simulating batch 12853
#  Simulating batch 12854
#  Simulating batch 12855
#  Simulating batch 12856
#  Simulating batch 12857
#  Simulating batch 12858
#  Simulating batch 12859
#  Simulating batch 12860
#  Simulating batch 12861
#  Simulating batch 12862
#  Simulating batch 12863
#  Simulating batch 12864
#  Simulating batch 12865
#  Simulating batch 12866
#  Simulating batch 12867
#  Simulating batch 12868
#  Simulating batch 12869
#  Simulating batch 12870
#  Simulating batch 12871
#  Simulating batch 12872
#  Simulating batch 12873
#  Simulating batch 12874
#  Simulating batch 12875
#  Simulating batch 12876
#  Simulating batch 12877
#  Simulating batch 12878
#  Simulating batch 12879
#  Simulating batch 12880
#  Simulating batch 12881
#  Simulating batch 12882
#  Simulating batch 12883
#  Simulating batch 12884
#  Simulating batch 12885
#  Simulating batch 12886
#  Simulating batch 12887
#  Simulating batch 12888
#  Simulating batch 12889
#  Simulating batch 12890
#  Simulating batch 12891
#  Simulating batch 12892
#  Simulating batch 12893
#  Simulating batch 12894
#  Simulating batch 12895
#  Simulating batch 12896
#  Simulating batch 12897
# ...
#  Simulating batch 13371
#  Simulating batch 13372
#  Simulating batch 13373
#  Simulating batch 13374
#  Simulating batch 13375
#  Simulating batch 13376
#  Simulating batch 13377
#  Simulating batch 13378
#  Simulating batch 13379
#  Simulating batch 13380
#  Simulating batch 13381
#  Simulating batch 13382
#  Simulating batch 13383
#  Simulating batch 13384
#  Simulating batch 13385
#  Simulating batch 13386
#  Simulating batch 13387
#  Simulating batch 13388
#  Simulating batch 13389
#  Simulating batch 13390
#  Simulating batch 13391
#  Simulating batch 13392
#  Simulating batch 13393
#  Simulating batch 13394
#  Simulating batch 13395
#  Simulating batch 13396
#  Simulating batch 13397
#  Simulating batch 13398
#  Simulating batch 13399
#  Simulating batch 13400
#  Simulating batch 13401
#  Simulating batch 13402
#  Simulating batch 13403
#  Simulating batch 13404
#  Simulating batch 13405
#  Simulating batch 13406
#  Simulating batch 13407
#  Simulating batch 13408
#  Simulating batch 13409
#  Simulating batch 13410
#  Simulating batch 13411
#  Simulating batch 13412
#  Simulating batch 13413
#  Simulating batch 13414
#  Simulating batch 13415
#  Simulating batch 13416
#  Simulating batch 13417
#  Simulating batch 13418
#  Simulating batch 13419
#  Simulating batch 13420
#  Simulating batch 13421
#  Simulating batch 13422
#  Simulating batch 13423
#  Simulating batch 13424
#  Simulating batch 13425
#  Simulating batch 13426
#  Simulating batch 13427
#  Simulating batch 13428
#  Simulating batch 13429
#  Simulating batch 13430
#  Simulating batch 13431
#  Simulating batch 13432
#  Simulating batch 13433
#  Simulating batch 13434
#  Simulating batch 13435
#  Simulating batch 13436
#  Simulating batch 13437
#  Simulating batch 13438
#  Simulating batch 13439
#  Simulating batch 13440
#  Simulating batch 13441
#  Simulating batch 13442
#  Simulating batch 13443
#  Simulating batch 13444
#  Simulating batch 13445
#  Simulating batch 13446
#  Simulating batch 13447
#  Simulating batch 13448
#  Simulating batch 13449
#  Simulating batch 13450
#  Simulating batch 13451
#  Simulating batch 13452
#  Simulating batch 13453
#  Simulating batch 13454
#  Simulating batch 13455
#  Simulating batch 13456
#  Simulating batch 13457
#  Simulating batch 13458
#  Simulating batch 13459
#  Simulating batch 13460
#  Simulating batch 13461
#  Simulating batch 13462
#  Simulating batch 13463
#  Simulating batch 13464
#  Simulating batch 13465
#  Simulating batch 13466
#  Simulating batch 13467
#  Simulating batch 13468
#  Simulating batch 13469
#  Simulating batch 13470
#  Simulating batch 13471
#  Simulating batch 13472
#  Simulating batch 13473
#  Simulating batch 13474
#  Simulating batch 13475
#  Simulating batch 13476
#  Simulating batch 13477
#  Simulating batch 13478
#  Simulating batch 13479
#  Simulating batch 13480
#  Simulating batch 13481
#  Simulating batch 13482
#  Simulating batch 13483
#  Simulating batch 13484
#  Simulating batch 13485
#  Simulating batch 13486
#  Simulating batch 13487
#  Simulating batch 13488
#  Simulating batch 13489
#  Simulating batch 13490
#  Simulating batch 13491
#  Simulating batch 13492
#  Simulating batch 13493
#  Simulating batch 13494
#  Simulating batch 13495
#  Simulating batch 13496
#  Simulating batch 13497
#  Simulating batch 13498
#  Simulating batch 13499
#  Simulating batch 13500
#  Simulating batch 13501
#  Simulating batch 13502
#  Simulating batch 13503
#  Simulating batch 13504
#  Simulating batch 13505
#  Simulating batch 13506
#  Simulating batch 13507
#  Simulating batch 13508
#  Simulating batch 13509
#  Simulating batch 13510
#  Simulating batch 13511
#  Simulating batch 13512
#  Simulating batch 13513
#  Simulating batch 13514
#  Simulating batch 13515
#  Simulating batch 13516
#  Simulating batch 13517
#  Simulating batch 13518
#  Simulating batch 13519
#  Simulating batch 13520
#  Simulating batch 13521
#  Simulating batch 13522
#  Simulating batch 13523
#  Simulating batch 13524
#  Simulating batch 13525
#  Simulating batch 13526
#  Simulating batch 13527
#  Simulating batch 13528
#  Simulating batch 13529
#  Simulating batch 13530
#  Simulating batch 13531
#  Simulating batch 13532
#  Simulating batch 13533
#  Simulating batch 13534
#  Simulating batch 13535
#  Simulating batch 13536
#  Simulating batch 13537
#  Simulating batch 13538
#  Simulating batch 13539
#  Simulating batch 13540
#  Simulating batch 13541
#  Simulating batch 13542
#  Simulating batch 13543
#  Simulating batch 13544
#  Simulating batch 13545
#  Simulating batch 13546
#  Simulating batch 13547
#  Simulating batch 13548
#  Simulating batch 13549
#  Simulating batch 13550
#  Simulating batch 13551
#  Simulating batch 13552
#  Simulating batch 13553
#  Simulating batch 13554
#  Simulating batch 13555
#  Simulating batch 13556
#  Simulating batch 13557
#  Simulating batch 13558
#  Simulating batch 13559
#  Simulating batch 13560
#  Simulating batch 13561
#  Simulating batch 13562
#  Simulating batch 13563
#  Simulating batch 13564
#  Simulating batch 13565
#  Simulating batch 13566
#  Simulating batch 13567
#  Simulating batch 13568
#  Simulating batch 13569
#  Simulating batch 13570
#  Simulating batch 13571
#  Simulating batch 13572
#  Simulating batch 13573
#  Simulating batch 13574
#  Simulating batch 13575
#  Simulating batch 13576
#  Simulating batch 13577
#  Simulating batch 13578
#  Simulating batch 13579
#  Simulating batch 13580
#  Simulating batch 13581
#  Simulating batch 13582
#  Simulating batch 13583
#  Simulating batch 13584
#  Simulating batch 13585
#  Simulating batch 13586
#  Simulating batch 13587
#  Simulating batch 13588
#  Simulating batch 13589
#  Simulating batch 13590
#  Simulating batch 13591
#  Simulating batch 13592
#  Simulating batch 13593
#  Simulating batch 13594
#  Simulating batch 13595
#  Simulating batch 13596
#  Simulating batch 13597
#  Simulating batch 13598
#  Simulating batch 13599
#  Simulating batch 13600
#  Simulating batch 13601
#  Simulating batch 13602
#  Simulating batch 13603
#  Simulating batch 13604
#  Simulating batch 13605
#  Simulating batch 13606
#  Simulating batch 13607
#  Simulating batch 13608
#  Simulating batch 13609
#  Simulating batch 13610
#  Simulating batch 13611
#  Simulating batch 13612
#  Simulating batch 13613
#  Simulating batch 13614
#  Simulating batch 13615
#  Simulating batch 13616
#  Simulating batch 13617
#  Simulating batch 13618
#  Simulating batch 13619
#  Simulating batch 13620
#  Simulating batch 13621
#  Simulating batch 13622
#  Simulating batch 13623
#  Simulating batch 13624
#  Simulating batch 13625
#  Simulating batch 13626
#  Simulating batch 13627
#  Simulating batch 13628
#  Simulating batch 13629
#  Simulating batch 13630
#  Simulating batch 13631
#  Simulating batch 13632
#  Simulating batch 13633
#  Simulating batch 13634
#  Simulating batch 13635
#  Simulating batch 13636
#  Simulating batch 13637
#  Simulating batch 13638
#  Simulating batch 13639
#  Simulating batch 13640
#  Simulating batch 13641
#  Simulating batch 13642
#  Simulating batch 13643
#  Simulating batch 13644
#  Simulating batch 13645
#  Simulating batch 13646
#  Simulating batch 13647
#  Simulating batch 13648
#  Simulating batch 13649
#  Simulating batch 13650
#  Simulating batch 13651
#  Simulating batch 13652
#  Simulating batch 13653
#  Simulating batch 13654
#  Simulating batch 13655
#  Simulating batch 13656
#  Simulating batch 13657
#  Simulating batch 13658
#  Simulating batch 13659
#  Simulating batch 13660
#  Simulating batch 13661
#  Simulating batch 13662
#  Simulating batch 13663
#  Simulating batch 13664
#  Simulating batch 13665
#  Simulating batch 13666
#  Simulating batch 13667
#  Simulating batch 13668
#  Simulating batch 13669
#  Simulating batch 13670
#  Simulating batch 13671
#  Simulating batch 13672
#  Simulating batch 13673
#  Simulating batch 13674
#  Simulating batch 13675
#  Simulating batch 13676
#  Simulating batch 13677
#  Simulating batch 13678
#  Simulating batch 13679
#  Simulating batch 13680
#  Simulating batch 13681
#  Simulating batch 13682
#  Simulating batch 13683
#  Simulating batch 13684
#  Simulating batch 13685
#  Simulating batch 13686
#  Simulating batch 13687
#  Simulating batch 13688
#  Simulating batch 13689
#  Simulating batch 13690
#  Simulating batch 13691
#  Simulating batch 13692
#  Simulating batch 13693
#  Simulating batch 13694
#  Simulating batch 13695
#  Simulating batch 13696
#  Simulating batch 13697
#  Simulating batch 13698
#  Simulating batch 13699
#  Simulating batch 13700
#  Simulating batch 13701
#  Simulating batch 13702
#  Simulating batch 13703
#  Simulating batch 13704
#  Simulating batch 13705
#  Simulating batch 13706
#  Simulating batch 13707
#  Simulating batch 13708
#  Simulating batch 13709
#  Simulating batch 13710
#  Simulating batch 13711
#  Simulating batch 13712
#  Simulating batch 13713
#  Simulating batch 13714
#  Simulating batch 13715
#  Simulating batch 13716
#  Simulating batch 13717
#  Simulating batch 13718
#  Simulating batch 13719
#  Simulating batch 13720
#  Simulating batch 13721
#  Simulating batch 13722
#  Simulating batch 13723
#  Simulating batch 13724
#  Simulating batch 13725
#  Simulating batch 13726
#  Simulating batch 13727
#  Simulating batch 13728
#  Simulating batch 13729
#  Simulating batch 13730
#  Simulating batch 13731
#  Simulating batch 13732
#  Simulating batch 13733
#  Simulating batch 13734
#  Simulating batch 13735
#  Simulating batch 13736
#  Simulating batch 13737
#  Simulating batch 13738
#  Simulating batch 13739
#  Simulating batch 13740
#  Simulating batch 13741
#  Simulating batch 13742
#  Simulating batch 13743
#  Simulating batch 13744
#  Simulating batch 13745
#  Simulating batch 13746
#  Simulating batch 13747
#  Simulating batch 13748
#  Simulating batch 13749
#  Simulating batch 13750
#  Simulating batch 13751
#  Simulating batch 13752
#  Simulating batch 13753
#  Simulating batch 13754
#  Simulating batch 13755
#  Simulating batch 13756
#  Simulating batch 13757
#  Simulating batch 13758
#  Simulating batch 13759
#  Simulating batch 13760
#  Simulating batch 13761
#  Simulating batch 13762
#  Simulating batch 13763
#  Simulating batch 13764
#  Simulating batch 13765
#  Simulating batch 13766
#  Simulating batch 13767
#  Simulating batch 13768
#  Simulating batch 13769
#  Simulating batch 13770
#  Simulating batch 13771
#  Simulating batch 13772
#  Simulating batch 13773
#  Simulating batch 13774
#  Simulating batch 13775
#  Simulating batch 13776
#  Simulating batch 13777
#  Simulating batch 13778
#  Simulating batch 13779
#  Simulating batch 13780
#  Simulating batch 13781
#  Simulating batch 13782
#  Simulating batch 13783
#  Simulating batch 13784
#  Simulating batch 13785
#  Simulating batch 13786
#  Simulating batch 13787
#  Simulating batch 13788
#  Simulating batch 13789
#  Simulating batch 13790
#  Simulating batch 13791
#  Simulating batch 13792
#  Simulating batch 13793
#  Simulating batch 13794
#  Simulating batch 13795
#  Simulating batch 13796
#  Simulating batch 13797
#  Simulating batch 13798
#  Simulating batch 13799
#  Simulating batch 13800
#  Simulating batch 13801
#  Simulating batch 13802
#  Simulating batch 13803
#  Simulating batch 13804
#  Simulating batch 13805
#  Simulating batch 13806
#  Simulating batch 13807
#  Simulating batch 13808
#  Simulating batch 13809
#  Simulating batch 13810
#  Simulating batch 13811
#  Simulating batch 13812
#  Simulating batch 13813
#  Simulating batch 13814
#  Simulating batch 13815
#  Simulating batch 13816
#  Simulating batch 13817
#  Simulating batch 13818
#  Simulating batch 13819
#  Simulating batch 13820
#  Simulating batch 13821
#  Simulating batch 13822
#  Simulating batch 13823
#  Simulating batch 13824
#  Simulating batch 13825
#  Simulating batch 13826
#  Simulating batch 13827
#  Simulating batch 13828
#  Simulating batch 13829
#  Simulating batch 13830
#  Simulating batch 13831
#  Simulating batch 13832
#  Simulating batch 13833
#  Simulating batch 13834
#  Simulating batch 13835
#  Simulating batch 13836
#  Simulating batch 13837
#  Simulating batch 13838
#  Simulating batch 13839
#  Simulating batch 13840
#  Simulating batch 13841
#  Simulating batch 13842
#  Simulating batch 13843
#  Simulating batch 13844
#  Simulating batch 13845
#  Simulating batch 13846
#  Simulating batch 13847
#  Simulating batch 13848
#  Simulating batch 13849
#  Simulating batch 13850
#  Simulating batch 13851
#  Simulating batch 13852
#  Simulating batch 13853
#  Simulating batch 13854
#  Simulating batch 13855
#  Simulating batch 13856
#  Simulating batch 13857
#  Simulating batch 13858
#  Simulating batch 13859
#  Simulating batch 13860
#  Simulating batch 13861
#  Simulating batch 13862
#  Simulating batch 13863
#  Simulating batch 13864
#  Simulating batch 13865
#  Simulating batch 13866
#  Simulating batch 13867
#  Simulating batch 13868
#  Simulating batch 13869
#  Simulating batch 13870
#  Simulating batch 13871
#  Simulating batch 13872
#  Simulating batch 13873
#  Simulating batch 13874
#  Simulating batch 13875
#  Simulating batch 13876
#  Simulating batch 13877
#  Simulating batch 13878
#  Simulating batch 13879
#  Simulating batch 13880
#  Simulating batch 13881
#  Simulating batch 13882
#  Simulating batch 13883
#  Simulating batch 13884
#  Simulating batch 13885
#  Simulating batch 13886
#  Simulating batch 13887
#  Simulating batch 13888
#  Simulating batch 13889
#  Simulating batch 13890
#  Simulating batch 13891
#  Simulating batch 13892
#  Simulating batch 13893
#  Simulating batch 13894
#  Simulating batch 13895
#  Simulating batch 13896
#  Simulating batch 13897
#  Simulating batch 13898
#  Simulating batch 13899
#  Simulating batch 13900
#  Simulating batch 13901
#  Simulating batch 13902
#  Simulating batch 13903
#  Simulating batch 13904
#  Simulating batch 13905
#  Simulating batch 13906
#  Simulating batch 13907
#  Simulating batch 13908
#  Simulating batch 13909
#  Simulating batch 13910
#  Simulating batch 13911
#  Simulating batch 13912
#  Simulating batch 13913
#  Simulating batch 13914
#  Simulating batch 13915
#  Simulating batch 13916
#  Simulating batch 13917
#  Simulating batch 13918
#  Simulating batch 13919
#  Simulating batch 13920
#  Simulating batch 13921
#  Simulating batch 13922
#  Simulating batch 13923
#  Simulating batch 13924
#  Simulating batch 13925
#  Simulating batch 13926
#  Simulating batch 13927
#  Simulating batch 13928
#  Simulating batch 13929
#  Simulating batch 13930
#  Simulating batch 13931
#  Simulating batch 13932
#  Simulating batch 13933
#  Simulating batch 13934
#  Simulating batch 13935
#  Simulating batch 13936
#  Simulating batch 13937
#  Simulating batch 13938
#  Simulating batch 13939
#  Simulating batch 13940
#  Simulating batch 13941
#  Simulating batch 13942
#  Simulating batch 13943
#  Simulating batch 13944
#  Simulating batch 13945
#  Simulating batch 13946
#  Simulating batch 13947
#  Simulating batch 13948
#  Simulating batch 13949
#  Simulating batch 13950
#  Simulating batch 13951
#  Simulating batch 13952
#  Simulating batch 13953
#  Simulating batch 13954
#  Simulating batch 13955
#  Simulating batch 13956
#  Simulating batch 13957
#  Simulating batch 13958
#  Simulating batch 13959
#  Simulating batch 13960
#  Simulating batch 13961
#  Simulating batch 13962
#  Simulating batch 13963
#  Simulating batch 13964
#  Simulating batch 13965
#  Simulating batch 13966
#  Simulating batch 13967
#  Simulating batch 13968
#  Simulating batch 13969
#  Simulating batch 13970
#  Simulating batch 13971
#  Simulating batch 13972
#  Simulating batch 13973
#  Simulating batch 13974
#  Simulating batch 13975
#  Simulating batch 13976
#  Simulating batch 13977
#  Simulating batch 13978
#  Simulating batch 13979
#  Simulating batch 13980
#  Simulating batch 13981
#  Simulating batch 13982
#  Simulating batch 13983
#  Simulating batch 13984
#  Simulating batch 13985
#  Simulating batch 13986
#  Simulating batch 13987
#  Simulating batch 13988
#  Simulating batch 13989
#  Simulating batch 13990
#  Simulating batch 13991
#  Simulating batch 13992
#  Simulating batch 13993
#  Simulating batch 13994
#  Simulating batch 13995
#  Simulating batch 13996
#  Simulating batch 13997
#  Simulating batch 13998
#  Simulating batch 13999
#  Simulating batch 14000
#  Creating state point statepoint.14000.h5...
#  Exporting weight windows to weight_windows.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.6424e-01 seconds
#    Reading cross sections          = 1.4869e-01 seconds
#  Total time in simulation          = 4.5045e+03 seconds
#    Time in transport only          = 4.4858e+03 seconds
#    Time in active batches          = 4.5045e+03 seconds
#    Time accumulating tallies       = 1.6974e+01 seconds
#    Time writing statepoints        = 5.0853e-03 seconds
#  Total time for finalization       = 4.4685e-02 seconds
#  Total time elapsed                = 4.5055e+03 seconds
#  Calculation Rate (active)         = 3329.98 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.88226 +/- 0.00004
