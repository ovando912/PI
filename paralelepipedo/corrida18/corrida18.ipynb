# %% [markdown]
# # Definiciones

# %%
import openmc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob


def run_simulation(
    fuente: list,
    geometria: list,
    z0: float,
    z_track: float,
    N_particles: int,
    ww: bool,
    batches: int = 1000,
    statepoint_file: str = None,
) -> None:
    """
    Ejecuta una simulación en OpenMC con la configuración especificada.

    Parámetros:
        fuente (list):
            - Si tiene 1 elemento: se asume que es la ruta a un archivo de fuente.
            - Si tiene 2 elementos: se asume que es [fuente_energia, fuente_direccion] para fuente independiente.
                - fuente_energia puede ser:
                    - "monoenergetica": Fuente con energía fija.
                    - "espectro_fision": Fuente con espectro de fisión.
                    - "espectro_termico": Fuente con espectro térmico.
                - fuente_direccion puede ser:
                    - "colimada": Fuente con dirección fija.
                    - "isotropica": Fuente con distribución isotrópica.

        geometria (list): Parámetros geométricos:
            - geometria[0] (bool): Flag para indicar si existe región de vacío.
            - geometria[1] (float): L_x, ancho del paralelepípedo.
            - geometria[2] (float): L_y, ancho del paralelepípedo.
            - geometria[3] (float): L_z, altura del paralelepípedo.
            - Si geometria[0] es True, se esperan además:
                - geometria[4] (float): L_x_vacio.
                - geometria[5] (float): L_y_vacio.

        z0 (float): Posición en z donde empieza la simulación.
        z_track (float): Posición en z para la superficie de track.
        N_particles (int): Número de partículas a simular en total.
        outfile_name (str): Nombre del archivo de salida. Si es None, se usa el nombre por defecto.
        WW (bool): Si se activa, se generan weight windows.
    """
    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Configuración de secciones eficaces
    # ---------------------------------------------------------------------------------------------------------------------------------------
    openmc.config["cross_sections"] = (
        "/home/lucas/Documents/Proyecto_Integrador/endfb-viii.0-hdf5/cross_sections.xml"
    )

    # ----------------------------------------------------------------------------------------------------------------------------------------
    # Procesamiento de la fuente
    # ----------------------------------------------------------------------------------------------------------------------------------------
    # Si la longitud de la fuente es 1, se asume que es un archivo de fuente.
    # Si la longitud de la fuente es 2, se asume que es una fuente independiente.
    if len(fuente) == 1:
        # Procesar fuente cuando viene de archivo
        ruta_fuente = fuente[0]
        if ruta_fuente.lower().endswith(".xml"):
            # Si es un XML de OpenMC, leerlo con el parser de fuentes
            source = openmc.HistogramSource(
                path=ruta_fuente,
            )
        else:
            # Si no es XML, asumimos formato binario o HDF5 compatible con FileSource
            source = openmc.FileSource(ruta_fuente)
    elif len(fuente) == 2:
        fuente_energia, fuente_direccion = fuente
        source = openmc.IndependentSource()
        source.particle = "neutron"

        # Distribución espacial: se coloca en la región central de la geometría
        L_x, L_y = geometria[1], geometria[2]
        x_dist = openmc.stats.Uniform(-L_x / 2, L_x / 2)
        y_dist = openmc.stats.Uniform(-L_y / 2, L_y / 2)
        z_dist = openmc.stats.Discrete(z0 + 1e-6, 1)  # Se fija z muy cerca de z=0
        source.space = openmc.stats.CartesianIndependent(x_dist, y_dist, z_dist)

        # Distribución de energía
        if fuente_energia == "monoenergetica":
            source.energy = openmc.stats.Discrete([1e6], [1])

        # Distribución angular
        if fuente_direccion == "colimada":
            mu = openmc.stats.Discrete([1], [1])
            phi = openmc.stats.Uniform(0.0, 2 * np.pi)
            source.angle = openmc.stats.PolarAzimuthal(mu, phi)
    else:
        raise ValueError("El parámetro 'fuente' debe contener 1 o 2 elementos.")

    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Procesamiento de la geometría
    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Extraer parámetros geométricos
    vacio = geometria[0]
    L_x, L_y, L_z = geometria[1:4]
    if vacio:
        L_x_vacio, L_y_vacio = geometria[4:6]

    # Definir material: agua
    mat_agua = openmc.Material(name="agua")
    mat_agua.add_nuclide("H1", 2.0, "ao")
    mat_agua.add_nuclide("O16", 1.0, "ao")
    mat_agua.add_s_alpha_beta("c_H_in_H2O")
    mat_agua.set_density("g/cm3", 1.0)
    mats = openmc.Materials([mat_agua])
    mats.export_to_xml()

    # Definir superficies externas
    surfaces = {
        "x_min": openmc.XPlane(x0=-L_x / 2, boundary_type="vacuum"),
        "x_max": openmc.XPlane(x0=L_x / 2, boundary_type="vacuum"),
        "y_min": openmc.YPlane(y0=-L_y / 2, boundary_type="vacuum"),
        "y_max": openmc.YPlane(y0=L_y / 2, boundary_type="vacuum"),
        "z_min": openmc.ZPlane(z0=z0, boundary_type="vacuum"),
        "z_max": openmc.ZPlane(z0=L_z, boundary_type="vacuum"),
    }

    # Se agrega la superficie de registro para generar el track file
    if z_track is not None:
        surfaces.update(
            {
                "z_track": openmc.ZPlane(
                    z0=z_track, boundary_type="transmission", surface_id=70
                )
            }
        )

    # Si hay vacío, definir superficies internas
    if vacio:
        surfaces.update(
            {
                "x_min_vacio": openmc.XPlane(
                    x0=-L_x_vacio / 2, boundary_type="transmission"
                ),
                "x_max_vacio": openmc.XPlane(
                    x0=L_x_vacio / 2, boundary_type="transmission"
                ),
                "y_min_vacio": openmc.YPlane(
                    y0=-L_y_vacio / 2, boundary_type="transmission"
                ),
                "y_max_vacio": openmc.YPlane(
                    y0=L_y_vacio / 2, boundary_type="transmission"
                ),
            }
        )

    # Para fuente tipo FileSource se traduce la superficie inferior para posicionar z0.
    # Sino se hace entonces las particulas aparecer fuera de la geometria.
    if len(fuente) == 1:
        surfaces["z_min"].translate(vector=(0, 0, -1e-6), inplace=True)

    # Definir regiones
    region_externa = (
        +surfaces["x_min"]
        & -surfaces["x_max"]
        & +surfaces["y_min"]
        & -surfaces["y_max"]
        & +surfaces["z_min"]
        & -surfaces["z_max"]
    )

    if vacio:
        region_vacio = (
            +surfaces["x_min_vacio"]
            & -surfaces["x_max_vacio"]
            & +surfaces["y_min_vacio"]
            & -surfaces["y_max_vacio"]
            & +surfaces["z_min"]
            & -surfaces["z_max"]
        )

    # Crear universo y definir celdas según configuración de fuente y vacío
    universe = openmc.Universe()

    if vacio:
        if z_track is not None:
            universe.add_cell(
                openmc.Cell(
                    region=region_externa & ~region_vacio & -surfaces["z_track"],
                    fill=mat_agua,
                    name="agua1",
                )
            )
            universe.add_cell(
                openmc.Cell(
                    region=region_externa & ~region_vacio & +surfaces["z_track"],
                    fill=mat_agua,
                    name="agua2",
                )
            )
            universe.add_cell(
                openmc.Cell(
                    region=region_vacio & -surfaces["z_track"],
                    fill=None,
                    name="vacio1",
                )
            )
            universe.add_cell(
                openmc.Cell(
                    region=region_vacio & +surfaces["z_track"],
                    fill=None,
                    name="vacio2",
                )
            )
        else:
            universe.add_cell(
                openmc.Cell(
                    region=region_externa & ~region_vacio,
                    fill=mat_agua,
                    name="agua",
                )
            )
            universe.add_cell(openmc.Cell(region=region_vacio, fill=None, name="vacio"))
    else:
        if z_track is not None:
            universe.add_cell(
                openmc.Cell(
                    region=region_externa & -surfaces["z_track"],
                    fill=mat_agua,
                    name="agua1",
                )
            )
            universe.add_cell(
                openmc.Cell(
                    region=region_externa & +surfaces["z_track"],
                    fill=mat_agua,
                    name="agua2",
                )
            )
        else:
            universe.add_cell(
                openmc.Cell(region=region_externa, fill=mat_agua, name="agua")
            )

    geom = openmc.Geometry(universe)
    geom.export_to_xml()

    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Configuración de settings
    # ---------------------------------------------------------------------------------------------------------------------------------------
    settings = openmc.Settings()
    settings.surf_source_write = {"surface_ids": [70], "max_particles": 20000000}
    settings.run_mode = "fixed source"
    settings.batches = batches
    settings.particles = int(N_particles)
    settings.source = source

    # Se definen las ventanas de peso
    if ww:
        # Define weight window spatial mesh
        ww_mesh = openmc.RegularMesh()
        ww_mesh.dimension = (10, 10, 100)
        ww_mesh.lower_left = (-L_x / 2, -L_y / 2, z0)
        ww_mesh.upper_right = (L_x / 2, L_y / 2, L_z)

        # Create weight window object and adjust parameters
        wwg = openmc.WeightWindowGenerator(
            method="magic",
            mesh=ww_mesh,
            max_realizations=settings.batches,
            energy_bounds=[0, 1, 1e3, 1e7],
            update_interval=50,
        )

        # Add generator to Settings instance
        settings.weight_window_generators = wwg
    settings.export_to_xml()

    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Configuración de tallies
    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Tally: malla para flujo total
    mesh = openmc.RectilinearMesh()
    mesh.x_grid = np.linspace(-L_x / 2, L_x / 2, 2)
    mesh.y_grid = np.linspace(-L_y / 2, L_y / 2, 2)
    mesh.z_grid = np.linspace(z0, L_z, 51)
    mesh_filter = openmc.MeshFilter(mesh)
    tally_flux_total = openmc.Tally(name="flux_total")
    tally_flux_total.filters = [mesh_filter]
    tally_flux_total.scores = ["flux"]

    # Tally: malla para flujo en vacio
    if vacio:
        mesh_vacio = openmc.RectilinearMesh()
        mesh_vacio.x_grid = np.linspace(-L_x_vacio / 2, L_x_vacio / 2, 2)
        mesh_vacio.y_grid = np.linspace(-L_y_vacio / 2, L_y_vacio / 2, 2)
        mesh_vacio.z_grid = np.linspace(z0, L_z, 51)
        mesh_filter_vacio = openmc.MeshFilter(mesh_vacio)
        tally_flux_vacio = openmc.Tally(name="flux_vacio")
        tally_flux_vacio.filters = [mesh_filter_vacio]
        tally_flux_vacio.scores = ["flux"]

    tallies = openmc.Tallies(
        [tally_flux_total, tally_flux_vacio] if vacio else [tally_flux_total]
    )

    tallies.export_to_xml()

    # ---------------------------------------------------------------------------------------------------------------------------------------
    # Limpieza de archivos previos y ejecución de la simulación
    # ---------------------------------------------------------------------------------------------------------------------------------------
    if statepoint_file is None:
        for file in glob.glob("statepoint.*.h5"):
            os.remove(file)
        if os.path.exists("summary.h5"):
            os.remove("summary.h5")

        openmc.run()
    else:
        openmc.run(restart_file=statepoint_file)

# %% [markdown]
# # Configuracion

# %%
geometria = [True, 15, 15, 100, 3, 3]
z0 = 15
z_track = 80
fuente = ["/home/lucas/Documents/Proyecto_Integrador/PI/resampleo_trackfiles/trackfile5/config1/source.xml"]
num_particles = int(5e3)
batches = 7500
WW = True
simulaciones_hechas = 15
simulaciones_por_hacer = 3

# for i in range(simulaciones_por_hacer):
#     sim_dir = f"sim{i+1+simulaciones_hechas}"
#     os.makedirs(sim_dir, exist_ok=True)
#     os.chdir(sim_dir)
#     print(f"Ejecutando simulación {i+1}")
#     run_simulation(
#         fuente=fuente,
#         geometria=geometria,
#         z0=z0,
#         z_track=z_track,
#         N_particles=num_particles,
#         ww=WW,
#     )
#     os.chdir("..")

run_simulation(
    fuente=fuente,
    geometria=geometria,
    z0=z0,
    z_track=z_track,
    N_particles=num_particles,
    batches=batches,
    ww=WW,
    statepoint_file="statepoint.6500.h5",
)

# Renombrar el archivo surface_source.h5 para incluir el número de batches
if os.path.exists('surface_source.h5'):
    os.rename('surface_source.h5', f'surface_source_{batches}.h5')
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2024 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.1-dev
#        Date/Time | 2025-05-21 07:16:16
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H1 from
#  /home/lucas/Documents/Proyecto_Integrador/endfb-viii.0-hdf5/neutron/H1.h5
#  Reading O16 from
#  /home/lucas/Documents/Proyecto_Integrador/endfb-viii.0-hdf5/neutron/O16.h5
#  Reading c_H_in_H2O from
#  /home/lucas/Documents/Proyecto_Integrador/endfb-viii.0-hdf5/neutron/c_H_in_H2O.h
#  5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Loading state point statepoint.6500.h5...
#  Resuming simulation...
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 6501
#  Simulating batch 6502
#  Simulating batch 6503
#  Simulating batch 6504
#  Simulating batch 6505
#  Simulating batch 6506
#  Simulating batch 6507
#  Simulating batch 6508
#  Simulating batch 6509
#  Simulating batch 6510
#  Simulating batch 6511
#  Simulating batch 6512
#  Simulating batch 6513
#  Simulating batch 6514
#  Simulating batch 6515
#  Simulating batch 6516
#  Simulating batch 6517
#  Simulating batch 6518
#  Simulating batch 6519
#  Simulating batch 6520
#  Simulating batch 6521
#  Simulating batch 6522
#  Simulating batch 6523
#  Simulating batch 6524
#  Simulating batch 6525
#  Simulating batch 6526
#  Simulating batch 6527
#  Simulating batch 6528
#  Simulating batch 6529
#  Simulating batch 6530
#  Simulating batch 6531
#  Simulating batch 6532
#  Simulating batch 6533
#  Simulating batch 6534
#  Simulating batch 6535
#  Simulating batch 6536
#  Simulating batch 6537
#  Simulating batch 6538
#  Simulating batch 6539
#  Simulating batch 6540
#  Simulating batch 6541
#  Simulating batch 6542
#  Simulating batch 6543
#  Simulating batch 6544
#  Simulating batch 6545
#  Simulating batch 6546
#  Simulating batch 6547
#  Simulating batch 6548
#  Simulating batch 6549
#  Simulating batch 6550
#  Simulating batch 6551
#  Simulating batch 6552
#  Simulating batch 6553
#  Simulating batch 6554
#  Simulating batch 6555
#  Simulating batch 6556
#  Simulating batch 6557
#  Simulating batch 6558
#  Simulating batch 6559
#  Simulating batch 6560
#  Simulating batch 6561
#  Simulating batch 6562
#  Simulating batch 6563
#  Simulating batch 6564
#  Simulating batch 6565
#  Simulating batch 6566
#  Simulating batch 6567
#  Simulating batch 6568
#  Simulating batch 6569
#  Simulating batch 6570
#  Simulating batch 6571
#  Simulating batch 6572
#  Simulating batch 6573
#  Simulating batch 6574
#  Simulating batch 6575
#  Simulating batch 6576
#  Simulating batch 6577
#  Simulating batch 6578
#  Simulating batch 6579
#  Simulating batch 6580
#  Simulating batch 6581
#  Simulating batch 6582
#  Simulating batch 6583
#  Simulating batch 6584
#  Simulating batch 6585
#  Simulating batch 6586
#  Simulating batch 6587
#  Simulating batch 6588
#  Simulating batch 6589
#  Simulating batch 6590
#  Simulating batch 6591
#  Simulating batch 6592
#  Simulating batch 6593
#  Simulating batch 6594
#  Simulating batch 6595
#  Simulating batch 6596
#  Simulating batch 6597
#  Simulating batch 6598
#  Simulating batch 6599
#  Simulating batch 6600
#  Simulating batch 6601
#  Simulating batch 6602
#  Simulating batch 6603
#  Simulating batch 6604
#  Simulating batch 6605
#  Simulating batch 6606
#  Simulating batch 6607
#  Simulating batch 6608
#  Simulating batch 6609
#  Simulating batch 6610
#  Simulating batch 6611
#  Simulating batch 6612
#  Simulating batch 6613
#  Simulating batch 6614
#  Simulating batch 6615
#  Simulating batch 6616
#  Simulating batch 6617
#  Simulating batch 6618
#  Simulating batch 6619
#  Simulating batch 6620
#  Simulating batch 6621
#  Simulating batch 6622
#  Simulating batch 6623
#  Simulating batch 6624
#  Simulating batch 6625
#  Simulating batch 6626
#  Simulating batch 6627
#  Simulating batch 6628
#  Simulating batch 6629
#  Simulating batch 6630
#  Simulating batch 6631
#  Simulating batch 6632
#  Simulating batch 6633
#  Simulating batch 6634
#  Simulating batch 6635
#  Simulating batch 6636
#  Simulating batch 6637
#  Simulating batch 6638
#  Simulating batch 6639
#  Simulating batch 6640
#  Simulating batch 6641
#  Simulating batch 6642
#  Simulating batch 6643
#  Simulating batch 6644
#  Simulating batch 6645
#  Simulating batch 6646
#  Simulating batch 6647
#  Simulating batch 6648
#  Simulating batch 6649
#  Simulating batch 6650
#  Simulating batch 6651
#  Simulating batch 6652
#  Simulating batch 6653
#  Simulating batch 6654
#  Simulating batch 6655
#  Simulating batch 6656
#  Simulating batch 6657
#  Simulating batch 6658
#  Simulating batch 6659
#  Simulating batch 6660
#  Simulating batch 6661
#  Simulating batch 6662
#  Simulating batch 6663
#  Simulating batch 6664
#  Simulating batch 6665
#  Simulating batch 6666
#  Simulating batch 6667
#  Simulating batch 6668
#  Simulating batch 6669
#  Simulating batch 6670
#  Simulating batch 6671
#  Simulating batch 6672
#  Simulating batch 6673
#  Simulating batch 6674
#  Simulating batch 6675
#  Simulating batch 6676
#  Simulating batch 6677
#  Simulating batch 6678
#  Simulating batch 6679
#  Simulating batch 6680
#  Simulating batch 6681
#  Simulating batch 6682
#  Simulating batch 6683
#  Simulating batch 6684
#  Simulating batch 6685
#  Simulating batch 6686
#  Simulating batch 6687
#  Simulating batch 6688
#  Simulating batch 6689
#  Simulating batch 6690
#  Simulating batch 6691
#  Simulating batch 6692
#  Simulating batch 6693
#  Simulating batch 6694
#  Simulating batch 6695
#  Simulating batch 6696
#  Simulating batch 6697
#  Simulating batch 6698
#  Simulating batch 6699
#  Simulating batch 6700
#  Simulating batch 6701
#  Simulating batch 6702
#  Simulating batch 6703
#  Simulating batch 6704
#  Simulating batch 6705
#  Simulating batch 6706
#  Simulating batch 6707
#  Simulating batch 6708
#  Simulating batch 6709
#  Simulating batch 6710
#  Simulating batch 6711
#  Simulating batch 6712
#  Simulating batch 6713
#  Simulating batch 6714
#  Simulating batch 6715
#  Simulating batch 6716
#  Simulating batch 6717
#  Simulating batch 6718
#  Simulating batch 6719
#  Simulating batch 6720
#  Simulating batch 6721
#  Simulating batch 6722
#  Simulating batch 6723
#  Simulating batch 6724
#  Simulating batch 6725
#  Simulating batch 6726
#  Simulating batch 6727
#  Simulating batch 6728
#  Simulating batch 6729
#  Simulating batch 6730
#  Simulating batch 6731
#  Simulating batch 6732
#  Simulating batch 6733
#  Simulating batch 6734
#  Simulating batch 6735
#  Simulating batch 6736
#  Simulating batch 6737
#  Simulating batch 6738
#  Simulating batch 6739
#  Simulating batch 6740
#  Simulating batch 6741
#  Simulating batch 6742
#  Simulating batch 6743
#  Simulating batch 6744
#  Simulating batch 6745
#  Simulating batch 6746
#  Simulating batch 6747
#  Simulating batch 6748
#  Simulating batch 6749
#  Simulating batch 6750
#  Simulating batch 6751
#  Simulating batch 6752
#  Simulating batch 6753
#  Simulating batch 6754
#  Simulating batch 6755
#  Simulating batch 6756
#  Simulating batch 6757
#  Simulating batch 6758
#  Simulating batch 6759
#  Simulating batch 6760
#  Simulating batch 6761
#  Simulating batch 6762
#  Simulating batch 6763
#  Simulating batch 6764
#  Simulating batch 6765
#  Simulating batch 6766
#  Simulating batch 6767
#  Simulating batch 6768
#  Simulating batch 6769
#  Simulating batch 6770
#  Simulating batch 6771
#  Simulating batch 6772
#  Simulating batch 6773
#  Simulating batch 6774
#  Simulating batch 6775
#  Simulating batch 6776
#  Simulating batch 6777
#  Simulating batch 6778
#  Simulating batch 6779
#  Simulating batch 6780
#  Simulating batch 6781
#  Simulating batch 6782
#  Simulating batch 6783
#  Simulating batch 6784
#  Simulating batch 6785
#  Simulating batch 6786
#  Simulating batch 6787
#  Simulating batch 6788
#  Simulating batch 6789
#  Simulating batch 6790
#  Simulating batch 6791
#  Simulating batch 6792
#  Simulating batch 6793
#  Simulating batch 6794
#  Simulating batch 6795
#  Simulating batch 6796
#  Simulating batch 6797
#  Simulating batch 6798
#  Simulating batch 6799
#  Simulating batch 6800
#  Simulating batch 6801
#  Simulating batch 6802
#  Simulating batch 6803
#  Simulating batch 6804
#  Simulating batch 6805
#  Simulating batch 6806
#  Simulating batch 6807
#  Simulating batch 6808
#  Simulating batch 6809
#  Simulating batch 6810
#  Simulating batch 6811
#  Simulating batch 6812
#  Simulating batch 6813
#  Simulating batch 6814
#  Simulating batch 6815
#  Simulating batch 6816
#  Simulating batch 6817
#  Simulating batch 6818
#  Simulating batch 6819
#  Simulating batch 6820
#  Simulating batch 6821
#  Simulating batch 6822
#  Simulating batch 6823
#  Simulating batch 6824
#  Simulating batch 6825
#  Simulating batch 6826
#  Simulating batch 6827
#  Simulating batch 6828
#  Simulating batch 6829
#  Simulating batch 6830
#  Simulating batch 6831
#  Simulating batch 6832
#  Simulating batch 6833
#  Simulating batch 6834
#  Simulating batch 6835
#  Simulating batch 6836
#  Simulating batch 6837
#  Simulating batch 6838
#  Simulating batch 6839
#  Simulating batch 6840
#  Simulating batch 6841
#  Simulating batch 6842
#  Simulating batch 6843
#  Simulating batch 6844
#  Simulating batch 6845
#  Simulating batch 6846
#  Simulating batch 6847
#  Simulating batch 6848
#  Simulating batch 6849
#  Simulating batch 6850
#  Simulating batch 6851
#  Simulating batch 6852
#  Simulating batch 6853
#  Simulating batch 6854
#  Simulating batch 6855
#  Simulating batch 6856
#  Simulating batch 6857
#  Simulating batch 6858
#  Simulating batch 6859
#  Simulating batch 6860
#  Simulating batch 6861
#  Simulating batch 6862
#  Simulating batch 6863
#  Simulating batch 6864
#  Simulating batch 6865
#  Simulating batch 6866
#  Simulating batch 6867
#  Simulating batch 6868
#  Simulating batch 6869
#  Simulating batch 6870
#  Simulating batch 6871
#  Simulating batch 6872
#  Simulating batch 6873
#  Simulating batch 6874
#  Simulating batch 6875
#  Simulating batch 6876
#  Simulating batch 6877
#  Simulating batch 6878
#  Simulating batch 6879
#  Simulating batch 6880
#  Simulating batch 6881
#  Simulating batch 6882
#  Simulating batch 6883
#  Simulating batch 6884
#  Simulating batch 6885
#  Simulating batch 6886
#  Simulating batch 6887
#  Simulating batch 6888
#  Simulating batch 6889
#  Simulating batch 6890
#  Simulating batch 6891
#  Simulating batch 6892
#  Simulating batch 6893
#  Simulating batch 6894
#  Simulating batch 6895
#  Simulating batch 6896
#  Simulating batch 6897
#  Simulating batch 6898
#  Simulating batch 6899
#  Simulating batch 6900
#  Simulating batch 6901
#  Simulating batch 6902
#  Simulating batch 6903
#  Simulating batch 6904
#  Simulating batch 6905
#  Simulating batch 6906
#  Simulating batch 6907
#  Simulating batch 6908
#  Simulating batch 6909
#  Simulating batch 6910
#  Simulating batch 6911
#  Simulating batch 6912
#  Simulating batch 6913
#  Simulating batch 6914
#  Simulating batch 6915
#  Simulating batch 6916
#  Simulating batch 6917
#  Simulating batch 6918
#  Simulating batch 6919
#  Simulating batch 6920
#  Simulating batch 6921
#  Simulating batch 6922
#  Simulating batch 6923
#  Simulating batch 6924
#  Simulating batch 6925
#  Simulating batch 6926
#  Simulating batch 6927
#  Simulating batch 6928
#  Simulating batch 6929
#  Simulating batch 6930
#  Simulating batch 6931
#  Simulating batch 6932
#  Simulating batch 6933
#  Simulating batch 6934
#  Simulating batch 6935
#  Simulating batch 6936
#  Simulating batch 6937
#  Simulating batch 6938
#  Simulating batch 6939
#  Simulating batch 6940
#  Simulating batch 6941
#  Simulating batch 6942
#  Simulating batch 6943
#  Simulating batch 6944
#  Simulating batch 6945
#  Simulating batch 6946
#  Simulating batch 6947
#  Simulating batch 6948
#  Simulating batch 6949
#  Simulating batch 6950
#  Simulating batch 6951
#  Simulating batch 6952
#  Simulating batch 6953
#  Simulating batch 6954
#  Simulating batch 6955
#  Simulating batch 6956
#  Simulating batch 6957
#  Simulating batch 6958
#  Simulating batch 6959
#  Simulating batch 6960
#  Simulating batch 6961
#  Simulating batch 6962
#  Simulating batch 6963
#  Simulating batch 6964
#  Simulating batch 6965
#  Simulating batch 6966
#  Simulating batch 6967
#  Simulating batch 6968
#  Simulating batch 6969
#  Simulating batch 6970
#  Simulating batch 6971
#  Simulating batch 6972
#  Simulating batch 6973
#  Simulating batch 6974
#  Simulating batch 6975
#  Simulating batch 6976
#  Simulating batch 6977
#  Simulating batch 6978
#  Simulating batch 6979
#  Simulating batch 6980
#  Simulating batch 6981
#  Simulating batch 6982
#  Simulating batch 6983
#  Simulating batch 6984
#  Simulating batch 6985
#  Simulating batch 6986
#  Simulating batch 6987
#  Simulating batch 6988
#  Simulating batch 6989
#  Simulating batch 6990
#  Simulating batch 6991
#  Simulating batch 6992
#  Simulating batch 6993
#  Simulating batch 6994
#  Simulating batch 6995
#  Simulating batch 6996
#  Simulating batch 6997
#  Simulating batch 6998
#  Simulating batch 6999
#  Simulating batch 7000
#  Simulating batch 7001
#  Simulating batch 7002
#  Simulating batch 7003
#  Simulating batch 7004
#  Simulating batch 7005
#  Simulating batch 7006
#  Simulating batch 7007
#  Simulating batch 7008
#  Simulating batch 7009
#  Simulating batch 7010
#  Simulating batch 7011
#  Simulating batch 7012
#  Simulating batch 7013
#  Simulating batch 7014
#  Simulating batch 7015
#  Simulating batch 7016
#  Simulating batch 7017
#  Simulating batch 7018
#  Simulating batch 7019
#  Simulating batch 7020
#  Simulating batch 7021
#  Simulating batch 7022
#  Simulating batch 7023
#  Simulating batch 7024
#  Simulating batch 7025
#  Simulating batch 7026
#  Simulating batch 7027
#  Simulating batch 7028
#  Simulating batch 7029
#  Simulating batch 7030
#  Simulating batch 7031
#  Simulating batch 7032
#  Simulating batch 7033
#  Simulating batch 7034
#  Simulating batch 7035
#  Simulating batch 7036
#  Simulating batch 7037
#  Simulating batch 7038
#  Simulating batch 7039
#  Simulating batch 7040
#  Simulating batch 7041
#  Simulating batch 7042
#  Simulating batch 7043
#  Simulating batch 7044
#  Simulating batch 7045
#  Simulating batch 7046
#  Simulating batch 7047
#  Simulating batch 7048
#  Simulating batch 7049
#  Simulating batch 7050
#  Simulating batch 7051
#  Simulating batch 7052
#  Simulating batch 7053
#  Simulating batch 7054
#  Simulating batch 7055
#  Simulating batch 7056
#  Simulating batch 7057
#  Simulating batch 7058
#  Simulating batch 7059
#  Simulating batch 7060
#  Simulating batch 7061
#  Simulating batch 7062
#  Simulating batch 7063
#  Simulating batch 7064
#  Simulating batch 7065
#  Simulating batch 7066
#  Simulating batch 7067
#  Simulating batch 7068
#  Simulating batch 7069
#  Simulating batch 7070
#  Simulating batch 7071
#  Simulating batch 7072
#  Simulating batch 7073
#  Simulating batch 7074
#  Simulating batch 7075
#  Simulating batch 7076
#  Simulating batch 7077
#  Simulating batch 7078
#  Simulating batch 7079
#  Simulating batch 7080
#  Simulating batch 7081
#  Simulating batch 7082
#  Simulating batch 7083
#  Simulating batch 7084
#  Simulating batch 7085
#  Simulating batch 7086
#  Simulating batch 7087
#  Simulating batch 7088
#  Simulating batch 7089
#  Simulating batch 7090
#  Simulating batch 7091
#  Simulating batch 7092
#  Simulating batch 7093
#  Simulating batch 7094
#  Simulating batch 7095
#  Simulating batch 7096
#  Simulating batch 7097
#  Simulating batch 7098
#  Simulating batch 7099
#  Simulating batch 7100
#  Simulating batch 7101
#  Simulating batch 7102
#  Simulating batch 7103
#  Simulating batch 7104
#  Simulating batch 7105
#  Simulating batch 7106
#  Simulating batch 7107
#  Simulating batch 7108
#  Simulating batch 7109
#  Simulating batch 7110
#  Simulating batch 7111
#  Simulating batch 7112
#  Simulating batch 7113
#  Simulating batch 7114
#  Simulating batch 7115
#  Simulating batch 7116
#  Simulating batch 7117
#  Simulating batch 7118
#  Simulating batch 7119
#  Simulating batch 7120
#  Simulating batch 7121
#  Simulating batch 7122
#  Simulating batch 7123
#  Simulating batch 7124
#  Simulating batch 7125
#  Simulating batch 7126
#  Simulating batch 7127
#  Simulating batch 7128
#  Simulating batch 7129
#  Simulating batch 7130
#  Simulating batch 7131
#  Simulating batch 7132
#  Simulating batch 7133
#  Simulating batch 7134
#  Simulating batch 7135
#  Simulating batch 7136
#  Simulating batch 7137
#  Simulating batch 7138
#  Simulating batch 7139
#  Simulating batch 7140
#  Simulating batch 7141
#  Simulating batch 7142
#  Simulating batch 7143
#  Simulating batch 7144
#  Simulating batch 7145
#  Simulating batch 7146
#  Simulating batch 7147
#  Simulating batch 7148
#  Simulating batch 7149
#  Simulating batch 7150
#  Simulating batch 7151
#  Simulating batch 7152
#  Simulating batch 7153
#  Simulating batch 7154
#  Simulating batch 7155
#  Simulating batch 7156
#  Simulating batch 7157
#  Simulating batch 7158
#  Simulating batch 7159
#  Simulating batch 7160
#  Simulating batch 7161
#  Simulating batch 7162
#  Simulating batch 7163
#  Simulating batch 7164
#  Simulating batch 7165
#  Simulating batch 7166
#  Simulating batch 7167
#  Simulating batch 7168
#  Simulating batch 7169
#  Simulating batch 7170
#  Simulating batch 7171
#  Simulating batch 7172
#  Simulating batch 7173
#  Simulating batch 7174
#  Simulating batch 7175
#  Simulating batch 7176
#  Simulating batch 7177
#  Simulating batch 7178
#  Simulating batch 7179
#  Simulating batch 7180
#  Simulating batch 7181
#  Simulating batch 7182
#  Simulating batch 7183
#  Simulating batch 7184
#  Simulating batch 7185
#  Simulating batch 7186
#  Simulating batch 7187
#  Simulating batch 7188
#  Simulating batch 7189
#  Simulating batch 7190
#  Simulating batch 7191
#  Simulating batch 7192
#  Simulating batch 7193
#  Simulating batch 7194
#  Simulating batch 7195
#  Simulating batch 7196
#  Simulating batch 7197
#  Simulating batch 7198
#  Simulating batch 7199
#  Simulating batch 7200
#  Simulating batch 7201
#  Simulating batch 7202
#  Simulating batch 7203
#  Simulating batch 7204
#  Simulating batch 7205
#  Simulating batch 7206
#  Simulating batch 7207
#  Simulating batch 7208
#  Simulating batch 7209
#  Simulating batch 7210
#  Simulating batch 7211
#  Simulating batch 7212
#  Simulating batch 7213
#  Simulating batch 7214
#  Simulating batch 7215
#  Simulating batch 7216
#  Simulating batch 7217
#  Simulating batch 7218
#  Simulating batch 7219
#  Simulating batch 7220
#  Simulating batch 7221
#  Simulating batch 7222
#  Simulating batch 7223
#  Simulating batch 7224
#  Simulating batch 7225
#  Simulating batch 7226
#  Simulating batch 7227
#  Simulating batch 7228
#  Simulating batch 7229
#  Simulating batch 7230
#  Simulating batch 7231
#  Simulating batch 7232
#  Simulating batch 7233
#  Simulating batch 7234
#  Simulating batch 7235
#  Simulating batch 7236
#  Simulating batch 7237
#  Simulating batch 7238
#  Simulating batch 7239
#  Simulating batch 7240
#  Simulating batch 7241
#  Simulating batch 7242
#  Simulating batch 7243
#  Simulating batch 7244
#  Simulating batch 7245
#  Simulating batch 7246
#  Simulating batch 7247
#  Simulating batch 7248
#  Simulating batch 7249
#  Simulating batch 7250
#  Simulating batch 7251
#  Simulating batch 7252
#  Simulating batch 7253
#  Simulating batch 7254
#  Simulating batch 7255
#  Simulating batch 7256
#  Simulating batch 7257
#  Simulating batch 7258
#  Simulating batch 7259
#  Simulating batch 7260
#  Simulating batch 7261
#  Simulating batch 7262
#  Simulating batch 7263
#  Simulating batch 7264
#  Simulating batch 7265
#  Simulating batch 7266
#  Simulating batch 7267
#  Simulating batch 7268
#  Simulating batch 7269
#  Simulating batch 7270
#  Simulating batch 7271
#  Simulating batch 7272
#  Simulating batch 7273
#  Simulating batch 7274
#  Simulating batch 7275
#  Simulating batch 7276
#  Simulating batch 7277
#  Simulating batch 7278
#  Simulating batch 7279
#  Simulating batch 7280
#  Simulating batch 7281
#  Simulating batch 7282
#  Simulating batch 7283
#  Simulating batch 7284
#  Simulating batch 7285
#  Simulating batch 7286
#  Simulating batch 7287
#  Simulating batch 7288
#  Simulating batch 7289
#  Simulating batch 7290
#  Simulating batch 7291
#  Simulating batch 7292
#  Simulating batch 7293
#  Simulating batch 7294
#  Simulating batch 7295
#  Simulating batch 7296
#  Simulating batch 7297
#  Simulating batch 7298
#  Simulating batch 7299
#  Simulating batch 7300
#  Simulating batch 7301
#  Simulating batch 7302
#  Simulating batch 7303
#  Simulating batch 7304
#  Simulating batch 7305
#  Simulating batch 7306
#  Simulating batch 7307
#  Simulating batch 7308
#  Simulating batch 7309
#  Simulating batch 7310
#  Simulating batch 7311
#  Simulating batch 7312
#  Simulating batch 7313
#  Simulating batch 7314
#  Simulating batch 7315
#  Simulating batch 7316
#  Simulating batch 7317
#  Simulating batch 7318
#  Simulating batch 7319
#  Simulating batch 7320
#  Simulating batch 7321
#  Simulating batch 7322
#  Simulating batch 7323
#  Simulating batch 7324
#  Simulating batch 7325
#  Simulating batch 7326
#  Simulating batch 7327
#  Simulating batch 7328
#  Simulating batch 7329
#  Simulating batch 7330
#  Simulating batch 7331
#  Simulating batch 7332
#  Simulating batch 7333
#  Simulating batch 7334
#  Simulating batch 7335
#  Simulating batch 7336
#  Simulating batch 7337
#  Simulating batch 7338
#  Simulating batch 7339
#  Simulating batch 7340
#  Simulating batch 7341
#  Simulating batch 7342
#  Simulating batch 7343
#  Simulating batch 7344
#  Simulating batch 7345
#  Simulating batch 7346
#  Simulating batch 7347
#  Simulating batch 7348
#  Simulating batch 7349
#  Simulating batch 7350
#  Simulating batch 7351
#  Simulating batch 7352
#  Simulating batch 7353
#  Simulating batch 7354
#  Simulating batch 7355
#  Simulating batch 7356
#  Simulating batch 7357
#  Simulating batch 7358
#  Simulating batch 7359
#  Simulating batch 7360
#  Simulating batch 7361
#  Simulating batch 7362
#  Simulating batch 7363
#  Simulating batch 7364
#  Simulating batch 7365
#  Simulating batch 7366
#  Simulating batch 7367
#  Simulating batch 7368
#  Simulating batch 7369
#  Simulating batch 7370
#  Simulating batch 7371
#  Simulating batch 7372
#  Simulating batch 7373
#  Simulating batch 7374
#  Simulating batch 7375
#  Simulating batch 7376
#  Simulating batch 7377
#  Simulating batch 7378
#  Simulating batch 7379
#  Simulating batch 7380
#  Simulating batch 7381
#  Simulating batch 7382
#  Simulating batch 7383
#  Simulating batch 7384
#  Simulating batch 7385
#  Simulating batch 7386
#  Simulating batch 7387
#  Simulating batch 7388
#  Simulating batch 7389
#  Simulating batch 7390
#  Simulating batch 7391
#  Simulating batch 7392
#  Simulating batch 7393
#  Simulating batch 7394
#  Simulating batch 7395
#  Simulating batch 7396
#  Simulating batch 7397
#  Simulating batch 7398
#  Simulating batch 7399
#  Simulating batch 7400
#  Simulating batch 7401
#  Simulating batch 7402
#  Simulating batch 7403
#  Simulating batch 7404
#  Simulating batch 7405
#  Simulating batch 7406
#  Simulating batch 7407
#  Simulating batch 7408
#  Simulating batch 7409
#  Simulating batch 7410
#  Simulating batch 7411
#  Simulating batch 7412
#  Simulating batch 7413
#  Simulating batch 7414
#  Simulating batch 7415
#  Simulating batch 7416
#  Simulating batch 7417
#  Simulating batch 7418
#  Simulating batch 7419
#  Simulating batch 7420
#  Simulating batch 7421
#  Simulating batch 7422
#  Simulating batch 7423
#  Simulating batch 7424
#  Simulating batch 7425
#  Simulating batch 7426
#  Simulating batch 7427
#  Simulating batch 7428
#  Simulating batch 7429
#  Simulating batch 7430
#  Simulating batch 7431
#  Simulating batch 7432
#  Simulating batch 7433
#  Simulating batch 7434
#  Simulating batch 7435
#  Simulating batch 7436
#  Simulating batch 7437
#  Simulating batch 7438
#  Simulating batch 7439
#  Simulating batch 7440
#  Simulating batch 7441
#  Simulating batch 7442
#  Simulating batch 7443
#  Simulating batch 7444
#  Simulating batch 7445
#  Simulating batch 7446
#  Simulating batch 7447
#  Simulating batch 7448
#  Simulating batch 7449
#  Simulating batch 7450
#  Simulating batch 7451
#  Simulating batch 7452
#  Simulating batch 7453
#  Simulating batch 7454
#  Simulating batch 7455
#  Simulating batch 7456
#  Simulating batch 7457
#  Simulating batch 7458
#  Simulating batch 7459
#  Simulating batch 7460
#  Simulating batch 7461
#  Simulating batch 7462
#  Simulating batch 7463
#  Simulating batch 7464
#  Simulating batch 7465
#  Simulating batch 7466
#  Simulating batch 7467
#  Simulating batch 7468
#  Simulating batch 7469
#  Simulating batch 7470
#  Simulating batch 7471
#  Simulating batch 7472
#  Simulating batch 7473
#  Simulating batch 7474
#  Simulating batch 7475
#  Simulating batch 7476
#  Simulating batch 7477
#  Simulating batch 7478
#  Simulating batch 7479
#  Simulating batch 7480
#  Simulating batch 7481
#  Simulating batch 7482
#  Simulating batch 7483
#  Simulating batch 7484
#  Simulating batch 7485
#  Simulating batch 7486
#  Simulating batch 7487
#  Simulating batch 7488
#  Simulating batch 7489
#  Simulating batch 7490
#  Simulating batch 7491
#  Simulating batch 7492
#  Simulating batch 7493
#  Simulating batch 7494
#  Simulating batch 7495
#  Simulating batch 7496
#  Simulating batch 7497
#  Simulating batch 7498
#  Simulating batch 7499
#  Simulating batch 7500
#  Creating state point statepoint.7500.h5...
#  Exporting weight windows to weight_windows.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.7566e-01 seconds
#    Reading cross sections          = 1.6370e-01 seconds
#  Total time in simulation          = 3.8831e+03 seconds
#    Time in transport only          = 3.8776e+03 seconds
#    Time in active batches          = 3.8831e+03 seconds
#    Time accumulating tallies       = 4.5906e+00 seconds
#    Time writing statepoints        = 5.2515e-03 seconds
#  Total time for finalization       = 4.6061e-02 seconds
#  Total time elapsed                = 3.8841e+03 seconds
#  Calculation Rate (active)         = 1287.61 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.89658 +/- 0.00005
